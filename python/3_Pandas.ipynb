# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas — пакет для статистической обработки данных, по функциональности близкий к SQL и R. Включает в себя функциональность работы с базами данных и таблицами Excel.

# %% [markdown]
# Обычно импорт выглядит так и к нему все привыкли:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Создание объекта

# %% [markdown]
# Создание `Серии` ([`Series`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html#pandas.Series)) путем передачи списка позволет pandas создать целочисленный индекс по умолчанию:

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Создание `DataFrame` ([`DataFrame`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html#pandas.DataFrame)) путем передачи массива NumPy :

# %%
# указываем начало временнОго периода и число повторений (дни по умолчанию)
dates = pd.date_range('20120101', periods=600,freq='ME')
dates
# Out:
# DatetimeIndex(['2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30',
#                '2012-05-31', '2012-06-30', '2012-07-31', '2012-08-31',
#                '2012-09-30', '2012-10-31',
#                ...
#                '2061-03-31', '2061-04-30', '2061-05-31', '2061-06-30',
#                '2061-07-31', '2061-08-31', '2061-09-30', '2061-10-31',
#                '2061-11-30', '2061-12-31'],
#               dtype='datetime64[ns]', length=600, freq='ME')

# %%
np.random.randn(600, 4)
# Out:
# array([[-0.50198798,  0.25683516, -0.5624825 , -0.04570283],
#        [ 0.82403425,  0.94331152, -0.75182539,  1.00400931],
#        [ 0.69922836,  0.72079433,  0.60113938, -0.34076555],
#        ...,
#        [-0.80929547,  0.18428169, -0.3992605 , -1.04074592],
#        [ 0.50724163, -1.20935232, -2.00745899,  0.10164013],
#        [ 0.07657722, -1.19383747,  0.76720203, -0.15285805]])

# %%
df = pd.DataFrame(np.random.randn(600, 4), index=dates, columns=['A','B','C','D'])
df
# Out:
#                    A         B         C         D
# 2012-01-31 -0.311412  0.667208  1.717706 -1.847369
# 2012-02-29  0.248808  0.044664  0.625272  1.730853
# 2012-03-31  0.804578 -0.081503  0.553259 -0.262377
# 2012-04-30  0.476569 -1.458649 -1.171720 -1.773515
# 2012-05-31 -0.001478 -0.996307  0.367370  0.140001
# ...              ...       ...       ...       ...
# 2061-08-31  0.314799 -0.082635 -0.249399  1.087080
# 2061-09-30 -2.012953  0.601205 -1.177553  1.591242
# 2061-10-31 -1.242894 -1.331563 -0.762655  0.825453
# 2061-11-30 -1.192910  0.329820 -0.181624 -0.949195
# 2061-12-31  0.878295 -0.039897  0.869247  0.218944
#
# [600 rows x 4 columns]

# %%
numbers_01 = np.arange(2, 12, 0.5, dtype=np.float32)
print(len(numbers_01))

series_num_01 = pd.Series(numbers_01)
print(series_num_01)
# Out:
# 20
# 0      2.0
# 1      2.5
# 2      3.0
# 3      3.5
# 4      4.0
# 5      4.5
# 6      5.0
# 7      5.5
# 8      6.0
# 9      6.5
# 10     7.0
# 11     7.5
# 12     8.0
# 13     8.5
# 14     9.0
# 15     9.5
# 16    10.0
# 17    10.5
# 18    11.0
# 19    11.5
# dtype: float32

# %%
numbers_02 = np.arange(2, 22, 0.5, dtype=np.float32)
print(len(numbers_02))
series_num_02 = pd.Series(numbers_02)
print(series_num_02)
# Out:
# 40
# 0      2.0
# 1      2.5
# 2      3.0
# 3      3.5
# 4      4.0
# 5      4.5
# 6      5.0
# 7      5.5
# 8      6.0
# 9      6.5
# 10     7.0
# 11     7.5
# 12     8.0
# 13     8.5
# 14     9.0
# 15     9.5
# 16    10.0
# 17    10.5
# 18    11.0
# 19    11.5
# 20    12.0
# 21    12.5
# 22    13.0
# 23    13.5
# 24    14.0
# 25    14.5
# 26    15.0
# 27    15.5
# 28    16.0
# 29    16.5
# 30    17.0
# 31    17.5
# 32    18.0
# 33    18.5
# 34    19.0
# 35    19.5
# 36    20.0
# 37    20.5
# 38    21.0
# 39    21.5
# dtype: float32

# %%
series_num_01 + series_num_02 # при сложении series разной длины, всё что сверх длины короткого Series, заполнится Nan
# Out:
# 0      4.0
# 1      5.0
# 2      6.0
# 3      7.0
# 4      8.0
# 5      9.0
# 6     10.0
# 7     11.0
# 8     12.0
# 9     13.0
# 10    14.0
# 11    15.0
# 12    16.0
# 13    17.0
# 14    18.0
# 15    19.0
# 16    20.0
# 17    21.0
# 18    22.0
# 19    23.0
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# 36     NaN
# 37     NaN
# 38     NaN
# 39     NaN
# dtype: float32

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %% [markdown]
# Включение категориальных данных в `DataFrame`, см. [введение в категории](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html#categorical)

# %%
pd.Categorical(["red", "green", "blue", "red"])
# Out:
# ['red', 'green', 'blue', 'red']
# Categories (3, object): ['blue', 'green', 'red']

# %%
dict_py = {'A': 1.,
            'B': pd.Timestamp('20130102'), # временнАя метка
            'C': pd.Series(1, index=list(range(4)), dtype='float32'), # Серия на основе списка
            'D': np.array([3] * 4, dtype='int32'), # массив целых чисел NumPy
            'E': pd.Categorical(["red", "green", "blue", "red"]), # категории
            'F': 'foobar'}

dict_py
# Out:
# {'A': 1.0,
#  'B': Timestamp('2013-01-02 00:00:00'),
#  'C': 0    1.0
#  1    1.0
#  2    1.0
#  3    1.0
#  dtype: float32,
#  'D': array([3, 3, 3, 3], dtype=int32),
#  'E': ['red', 'green', 'blue', 'red']
#  Categories (3, object): ['blue', 'green', 'red'],
#  'F': 'foobar'}

# %% [markdown]
# Создать [`DataFrame`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html#pandas.DataFrame) можно путем передачи словаря объектов.

# %%
df2 = pd.DataFrame(dict_py)
df2
# Out:
#      A          B    C  D      E       F
# 0  1.0 2013-01-02  1.0  3    red  foobar
# 1  1.0 2013-01-02  1.0  3  green  foobar
# 2  1.0 2013-01-02  1.0  3   blue  foobar
# 3  1.0 2013-01-02  1.0  3    red  foobar

# %% [markdown]
# Столбцы итогового [`DataFrame`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html#pandas.DataFrame) имеют разные [типы данных](https://pandas.pydata.org/pandas-docs/stable/user_guide/basics.html#basics-dtypes).

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %% [markdown]
# ## Просмотр данных

# %% [markdown]
# Просмотрим верхние и нижние строки полученного DataFrame:

# %%
df.head(15) # вывести первые 10 строк
# Out:
#                    A         B         C         D
# 2012-01-31 -0.311412  0.667208  1.717706 -1.847369
# 2012-02-29  0.248808  0.044664  0.625272  1.730853
# 2012-03-31  0.804578 -0.081503  0.553259 -0.262377
# 2012-04-30  0.476569 -1.458649 -1.171720 -1.773515
# 2012-05-31 -0.001478 -0.996307  0.367370  0.140001
# 2012-06-30  1.585082  0.067398  0.149100  1.236530
# 2012-07-31  0.606025  0.288407  0.004997  1.208718
# 2012-08-31 -1.783629 -0.692394 -1.253129  0.472508
# 2012-09-30  0.469248 -1.174504  0.198428 -0.308379
# 2012-10-31  0.575168 -0.337926  0.378607  1.549686
# 2012-11-30 -0.257932 -1.869790  0.075635 -0.810716
# 2012-12-31 -0.706510 -0.068075  2.874875  0.284778
# 2013-01-31  0.062229 -0.898127 -0.051427  1.077788
# 2013-02-28  0.152341 -0.400381 -1.287939  0.213011
# 2013-03-31  1.757002  0.932732  0.366139  1.903312

# %%
df.tail(15) # вывести последние три строки
# Out:
#                    A         B         C         D
# 2060-10-31  1.564791  0.727158  1.141835  2.821416
# 2060-11-30  0.412623  0.179233 -0.703159 -0.154326
# 2060-12-31  0.280233 -0.684128  0.050076 -0.734925
# 2061-01-31 -1.709198  1.416804  0.626682  0.645801
# 2061-02-28  0.196612  1.450873  0.712775  0.635733
# 2061-03-31  1.760953  1.026578  1.879497  0.570918
# 2061-04-30  0.091172 -0.633736 -0.745920 -0.659835
# 2061-05-31 -2.060853 -0.316440 -0.324916  1.397315
# 2061-06-30  0.270393 -1.469325  1.197017  0.587816
# 2061-07-31  0.268553 -0.601572 -2.080317 -0.779178
# 2061-08-31  0.314799 -0.082635 -0.249399  1.087080
# 2061-09-30 -2.012953  0.601205 -1.177553  1.591242
# 2061-10-31 -1.242894 -1.331563 -0.762655  0.825453
# 2061-11-30 -1.192910  0.329820 -0.181624 -0.949195
# 2061-12-31  0.878295 -0.039897  0.869247  0.218944

# %% [markdown]
# Отобразим индекс и названия столбцов:

# %%
df.index
# Out:
# DatetimeIndex(['2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30',
#                '2012-05-31', '2012-06-30', '2012-07-31', '2012-08-31',
#                '2012-09-30', '2012-10-31',
#                ...
#                '2061-03-31', '2061-04-30', '2061-05-31', '2061-06-30',
#                '2061-07-31', '2061-08-31', '2061-09-30', '2061-10-31',
#                '2061-11-30', '2061-12-31'],
#               dtype='datetime64[ns]', length=600, freq='ME')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# Метод [`DataFrame.to_numpy()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_numpy.html#pandas.DataFrame.to_numpy) представляет данные в виде массива NumPy, на котором строится DataFrame.

# %%
num_arr = df.to_numpy()
num_arr
# Out:
# array([[-0.31141236,  0.66720815,  1.71770558, -1.84736925],
#        [ 0.24880839,  0.04466423,  0.62527174,  1.73085341],
#        [ 0.80457767, -0.08150252,  0.55325914, -0.26237725],
#        ...,
#        [-1.24289423, -1.33156308, -0.762655  ,  0.82545307],
#        [-1.19290984,  0.32982012, -0.18162357, -0.94919525],
#        [ 0.87829494, -0.03989714,  0.86924736,  0.21894361]])

# %%
df.to_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35912\771943869.py in ?()
# ----> 1 df.to_list()
#
# c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_list'

# %%
df.to_numpy().flatten()
# Out:
# array([-0.31141236,  0.66720815,  1.71770558, ..., -0.03989714,
#         0.86924736,  0.21894361])

# %%
df.to_dict()
# Out:
# {'A': {Timestamp('2012-01-31 00:00:00'): -0.31141236301659725,
#   Timestamp('2012-02-29 00:00:00'): 0.24880839036409702,
#   Timestamp('2012-03-31 00:00:00'): 0.8045776741791452,
#   Timestamp('2012-04-30 00:00:00'): 0.47656882150960644,
#   Timestamp('2012-05-31 00:00:00'): -0.0014782057329237718,
#   Timestamp('2012-06-30 00:00:00'): 1.5850820616986345,
#   Timestamp('2012-07-31 00:00:00'): 0.6060252812910359,
#   Timestamp('2012-08-31 00:00:00'): -1.78362879448501,
#   Timestamp('2012-09-30 00:00:00'): 0.4692478912799219,
#   Timestamp('2012-10-31 00:00:00'): 0.5751684025563769,
#   Timestamp('2012-11-30 00:00:00'): -0.2579318089378089,
#   Timestamp('2012-12-31 00:00:00'): -0.7065097335002044,
#   Timestamp('2013-01-31 00:00:00'): 0.06222924490621912,
#   Timestamp('2013-02-28 00:00:00'): 0.1523407260175863,
#   Timestamp('2013-03-31 00:00:00'): 1.7570024152267363,
#   Timestamp('2013-04-30 00:00:00'): -1.1616086920487436,
#   Timestamp('2013-05-31 00:00:00'): 1.0680482362427735,
#   Timestamp('2013-06-30 00:00:00'): 1.23555880485748,
#   Timestamp('2013-07-31 00:00:00'): -1.2343261321217494,
#   Timestamp('2013-08-31 00:00:00'): 0.7302087262887493,
#   Timestamp('2013-09-30 00:00:00'): 0.648235270644747,
#   Timestamp('2013-10-31 00:00:00'): 2.4390118501883835,
#   Timestamp('2013-11-30 00:00:00'): -0.5147734294564702,
#   Timestamp('2013-12-31 00:00:00'): 1.2178241892600334,
#   Timestamp('2014-01-31 00:00:00'): -1.4360066761916797,
#   Timestamp('2014-02-28 00:00:00'): -1.0964260979795095,
#   Timestamp('2014-03-31 00:00:00'): -0.2606178651744114,
#   Timestamp('2014-04-30 00:00:00'): -0.8642358692378124,
#   Timestamp('2014-05-31 00:00:00'): 1.3728999114238722,
#   Timestamp('2014-06-30 00:00:00'): -0.35596232706305025,
#   Timestamp('2014-07-31 00:00:00'): 0.2551661575247855,
#   Timestamp('2014-08-31 00:00:00'): 0.8312668249952769,
#   Timestamp('2014-09-30 00:00:00'): 1.497763719080319,
#   Timestamp('2014-10-31 00:00:00'): 0.19083896851474902,
#   Timestamp('2014-11-30 00:00:00'): 0.679108579544389,
#   Timestamp('2014-12-31 00:00:00'): -1.4081561023155469,
#   Timestamp('2015-01-31 00:00:00'): -1.4504728152943118,
#   Timestamp('2015-02-28 00:00:00'): 1.7340916790019558,
#   Timestamp('2015-03-31 00:00:00'): 0.5419389200137634,
#   Timestamp('2015-04-30 00:00:00'): -0.8441851269081339,
#   Timestamp('2015-05-31 00:00:00'): -0.12042198084191492,
#   Timestamp('2015-06-30 00:00:00'): -0.40694346613095395,
#   Timestamp('2023-04-30 00:00:00'): 2.2156083550653216,
#   Timestamp('2023-05-31 00:00:00'): 1.262733035120141,
#   Timestamp('2023-06-30 00:00:00'): 0.41656086050376323,
#   Timestamp('2023-07-31 00:00:00'): -0.6109514781845994,
#   Timestamp('2023-08-31 00:00:00'): 0.590151248129295,
#   Timestamp('2023-09-30 00:00:00'): -1.755666438649974,
#   Timestamp('2023-10-31 00:00:00'): -0.7281492833425428,
#   Timestamp('2023-11-30 00:00:00'): 0.37951336410284486,
#   Timestamp('2023-12-31 00:00:00'): -0.11924664011057036,
#   Timestamp('2024-01-31 00:00:00'): -1.0344000404835287,
#   Timestamp('2024-02-29 00:00:00'): 0.21191530266515096,
#   Timestamp('2024-03-31 00:00:00'): -0.5216922752763852,
#   Timestamp('2024-04-30 00:00:00'): -0.6128446120990898,
#   Timestamp('2024-05-31 00:00:00'): 0.0314832486085949,
#   Timestamp('2024-06-30 00:00:00'): -0.8984445850118237,
#   Timestamp('2024-07-31 00:00:00'): 1.1547095564025947,
#   Timestamp('2024-08-31 00:00:00'): -0.026228692215669622,
#   Timestamp('2024-09-30 00:00:00'): 0.12890159181174998,
#   Timestamp('2024-10-31 00:00:00'): 0.5679963801515069,
#   Timestamp('2024-11-30 00:00:00'): -0.16994171374740272,
#   Timestamp('2024-12-31 00:00:00'): 0.9231985089997424,
#   Timestamp('2025-01-31 00:00:00'): -0.7394150145693172,
#   Timestamp('2025-02-28 00:00:00'): -0.7455686261465849,
#   Timestamp('2025-03-31 00:00:00'): 2.7462078893895914,
#   Timestamp('2025-04-30 00:00:00'): 0.22217328235388048,
#   Timestamp('2025-05-31 00:00:00'): 0.617089087438798,
#   Timestamp('2025-06-30 00:00:00'): 0.3486656650891123,
#   Timestamp('2025-07-31 00:00:00'): 0.8716974882094033,
#   Timestamp('2025-08-31 00:00:00'): 0.42329294454847516,
#   Timestamp('2025-09-30 00:00:00'): -0.922575561390157,
#   Timestamp('2025-10-31 00:00:00'): -1.7814041154288471,
#   Timestamp('2025-11-30 00:00:00'): -0.7037834096559682,
#   Timestamp('2025-12-31 00:00:00'): 2.593097639553493,
#   Timestamp('2026-01-31 00:00:00'): -0.029688348039895264,
#   Timestamp('2026-02-28 00:00:00'): -0.815693206611333,
#   Timestamp('2026-03-31 00:00:00'): -0.4905050830938787,
#   Timestamp('2026-04-30 00:00:00'): -0.3104072579833824,
#   Timestamp('2026-05-31 00:00:00'): 1.254003730739229,
#   Timestamp('2026-06-30 00:00:00'): -0.9310620325222373,
#   Timestamp('2026-07-31 00:00:00'): -0.7696611645227921,
#   Timestamp('2026-08-31 00:00:00'): 0.16597208865465224,
#   Timestamp('2026-09-30 00:00:00'): -1.4941925290949072,
#   Timestamp('2026-10-31 00:00:00'): -1.1267961987291855,
#   Timestamp('2026-11-30 00:00:00'): 0.7387157174603602,
#   Timestamp('2026-12-31 00:00:00'): -1.657317148509996,
#   Timestamp('2027-01-31 00:00:00'): -0.692938069323166,
#   Timestamp('2038-09-30 00:00:00'): 0.18324508868624567,
#   Timestamp('2038-10-31 00:00:00'): -0.0917750587263893,
#   Timestamp('2038-11-30 00:00:00'): -0.6894671667241842,
#   Timestamp('2038-12-31 00:00:00'): -0.520058481811221,
#   Timestamp('2039-01-31 00:00:00'): -0.5627268075874099,
#   Timestamp('2039-02-28 00:00:00'): 0.4218694426197323,
#   Timestamp('2039-03-31 00:00:00'): -0.8648454198512514,
#   Timestamp('2039-04-30 00:00:00'): -0.04231719723610351,
#   Timestamp('2039-05-31 00:00:00'): 0.9673755851844976,
#   Timestamp('2039-06-30 00:00:00'): 0.4742710897910322,
#   Timestamp('2039-07-31 00:00:00'): 1.895331123029715,
#   Timestamp('2039-08-31 00:00:00'): -0.04255967554831289,
#   Timestamp('2039-09-30 00:00:00'): -1.4354239159041446,
#   Timestamp('2039-10-31 00:00:00'): -0.12695095818371574,
#   Timestamp('2039-11-30 00:00:00'): 0.12305383515773144,
#   Timestamp('2039-12-31 00:00:00'): 0.890357146110492,
#   Timestamp('2040-01-31 00:00:00'): 1.4326934959685167,
#   Timestamp('2040-02-29 00:00:00'): -0.1749747664619608,
#   Timestamp('2040-03-31 00:00:00'): -0.10756799626085492,
#   Timestamp('2040-04-30 00:00:00'): 1.5745582475789657,
#   Timestamp('2040-05-31 00:00:00'): -1.5974384832312667,
#   Timestamp('2040-06-30 00:00:00'): -0.6637940379057005,
#   Timestamp('2040-07-31 00:00:00'): -1.121552761924111,
#   Timestamp('2040-08-31 00:00:00'): -0.03220768051240942,
#   Timestamp('2040-09-30 00:00:00'): 1.3255604462807542,
#   Timestamp('2040-10-31 00:00:00'): -0.2885806863270301,
#   Timestamp('2040-11-30 00:00:00'): 0.08393722387373309,
#   Timestamp('2040-12-31 00:00:00'): -0.6498466012864116,
#   Timestamp('2041-01-31 00:00:00'): -0.2796696007862282,
#   Timestamp('2041-02-28 00:00:00'): -1.5913091622680902,
#   Timestamp('2041-03-31 00:00:00'): -1.8050893539558863,
#   Timestamp('2041-04-30 00:00:00'): 0.26530182614300335,
#   Timestamp('2041-05-31 00:00:00'): -1.9370930551002243,
#   Timestamp('2041-06-30 00:00:00'): -1.5686805444404537,
#   Timestamp('2041-07-31 00:00:00'): -1.094449982235729,
#   Timestamp('2041-08-31 00:00:00'): 0.23863336651245548,
#   Timestamp('2041-09-30 00:00:00'): 0.33295077990042815,
#   Timestamp('2041-10-31 00:00:00'): 0.28433340675681906,
#   Timestamp('2041-11-30 00:00:00'): -1.777684257465938,
#   Timestamp('2041-12-31 00:00:00'): -1.4412837107253542,
#   Timestamp('2042-01-31 00:00:00'): 0.6592196644118185,
#   Timestamp('2042-02-28 00:00:00'): 0.686696738245041,
#   Timestamp('2042-03-31 00:00:00'): 0.3504043329316213,
#   Timestamp('2042-04-30 00:00:00'): 0.4638992098885351,
#   Timestamp('2042-05-31 00:00:00'): 0.5277372070275863,
#   Timestamp('2042-06-30 00:00:00'): -0.23296705659701036,
#   Timestamp('2042-07-31 00:00:00'): -0.5267108125886217,
#   Timestamp('2054-03-31 00:00:00'): 0.5127833267010405,
#   Timestamp('2054-04-30 00:00:00'): 1.8043104593785688,
#   Timestamp('2054-05-31 00:00:00'): 0.4814119055319212,
#   Timestamp('2054-06-30 00:00:00'): -0.5092210467414237,
#   Timestamp('2054-07-31 00:00:00'): 0.029720327298603647,
#   Timestamp('2054-08-31 00:00:00'): -0.35374869591072916,
#   Timestamp('2054-09-30 00:00:00'): -0.6461590379237265,
#   Timestamp('2054-10-31 00:00:00'): -0.4857705026955892,
#   Timestamp('2054-11-30 00:00:00'): -0.06817643542699509,
#   Timestamp('2054-12-31 00:00:00'): -0.255924201611186,
#   Timestamp('2055-01-31 00:00:00'): 1.5084539743861,
#   Timestamp('2055-02-28 00:00:00'): 1.0929475158678783,
#   Timestamp('2055-03-31 00:00:00'): 0.9415962031285466,
#   Timestamp('2055-04-30 00:00:00'): 0.15156394788128522,
#   Timestamp('2055-05-31 00:00:00'): 0.2524180428809664,
#   Timestamp('2055-06-30 00:00:00'): 0.3568981652997103,
#   Timestamp('2055-07-31 00:00:00'): 0.9753196453407652,
#   Timestamp('2055-08-31 00:00:00'): -2.0253521521345257,
#   Timestamp('2055-09-30 00:00:00'): 0.9847426167236791,
#   Timestamp('2055-10-31 00:00:00'): 1.2397712174816753,
#   Timestamp('2055-11-30 00:00:00'): 0.18690381075387036,
#   Timestamp('2055-12-31 00:00:00'): -0.22551273348044334,
#   Timestamp('2056-01-31 00:00:00'): -1.1627309227805394,
#   Timestamp('2056-02-29 00:00:00'): -1.0269613516650264,
#   Timestamp('2056-03-31 00:00:00'): 1.936720873051733,
#   Timestamp('2056-04-30 00:00:00'): 1.2876148486994907,
#   Timestamp('2056-05-31 00:00:00'): 0.012170738804700888,
#   Timestamp('2056-06-30 00:00:00'): -0.5482994241823617,
#   Timestamp('2056-07-31 00:00:00'): 2.3124041765010546,
#   Timestamp('2056-08-31 00:00:00'): -0.6751160416572753,
#   Timestamp('2056-09-30 00:00:00'): -1.1649625025100538,
#   Timestamp('2056-10-31 00:00:00'): -1.2751917132623245,
#   Timestamp('2056-11-30 00:00:00'): -0.9665179934623231,
#   Timestamp('2056-12-31 00:00:00'): 0.766923740331073,
#   Timestamp('2057-01-31 00:00:00'): 1.3276448995574002,
#   Timestamp('2057-02-28 00:00:00'): 0.296183900605781,
#   Timestamp('2057-03-31 00:00:00'): -0.9143589753509029,
#   Timestamp('2057-04-30 00:00:00'): 0.8112428876529516,
#   Timestamp('2057-05-31 00:00:00'): -0.4449737608028754,
#   Timestamp('2057-06-30 00:00:00'): -0.22443671007503155,
#   Timestamp('2057-07-31 00:00:00'): 0.7309334220326271,
#   Timestamp('2057-08-31 00:00:00'): -0.7495556242707748,
#   Timestamp('2057-09-30 00:00:00'): -1.0435602217061106,
#   Timestamp('2057-10-31 00:00:00'): 0.17887709103050278,
#   Timestamp('2057-11-30 00:00:00'): 0.15049089477458102,
#   Timestamp('2057-12-31 00:00:00'): -2.114372011324216,
#   Timestamp('2023-07-31 00:00:00'): -0.7870312093729754,
#   Timestamp('2023-08-31 00:00:00'): -0.8705893875161342,
#   Timestamp('2023-09-30 00:00:00'): 1.1360487788791098,
#   Timestamp('2023-10-31 00:00:00'): 0.8570576642711266,
#   Timestamp('2023-11-30 00:00:00'): -0.5836144813056405,
#   Timestamp('2023-12-31 00:00:00'): -0.8151836173831355,
#   Timestamp('2024-01-31 00:00:00'): -0.1927325939172742,
#   Timestamp('2024-02-29 00:00:00'): 0.9760008646728741,
#   Timestamp('2024-03-31 00:00:00'): 0.05072452652524248,
#   Timestamp('2024-04-30 00:00:00'): 1.0638704136871533,
#   Timestamp('2024-05-31 00:00:00'): 0.6333309477287994,
#   Timestamp('2024-06-30 00:00:00'): -0.0891353955835292,
#   Timestamp('2024-07-31 00:00:00'): -0.9750423629130147,
#   Timestamp('2024-08-31 00:00:00'): -0.9129611519024567,
#   Timestamp('2024-09-30 00:00:00'): 0.5879216401009915,
#   Timestamp('2024-10-31 00:00:00'): 1.3346489992225792,
#   Timestamp('2024-11-30 00:00:00'): 1.5049834086910496,
#   Timestamp('2024-12-31 00:00:00'): -0.7452396259905097,
#   Timestamp('2025-01-31 00:00:00'): -0.11318352949975279,
#   Timestamp('2025-02-28 00:00:00'): 1.501140165992657,
#   Timestamp('2025-03-31 00:00:00'): 0.0232160613270955,
#   Timestamp('2025-04-30 00:00:00'): -2.159725153039193,
#   Timestamp('2025-05-31 00:00:00'): -0.505809780296872,
#   Timestamp('2025-06-30 00:00:00'): -2.174779513735796,
#   Timestamp('2025-07-31 00:00:00'): 0.3266917715154943,
#   Timestamp('2025-08-31 00:00:00'): -0.7366694861334999,
#   Timestamp('2025-09-30 00:00:00'): -1.1390598973585486,
#   Timestamp('2025-10-31 00:00:00'): -1.347488123539453,
#   Timestamp('2025-11-30 00:00:00'): 0.883054210311981,
#   Timestamp('2025-12-31 00:00:00'): 0.615973698131076,
#   Timestamp('2026-01-31 00:00:00'): -0.4643089592984803,
#   Timestamp('2026-02-28 00:00:00'): 0.2430627626559982,
#   Timestamp('2026-03-31 00:00:00'): 0.9110950629210999,
#   Timestamp('2026-04-30 00:00:00'): 0.27026973397089277,
#   Timestamp('2026-05-31 00:00:00'): 0.28669139766315027,
#   Timestamp('2026-06-30 00:00:00'): 0.6944585178520851,
#   Timestamp('2026-07-31 00:00:00'): 1.4805490376158403,
#   Timestamp('2026-08-31 00:00:00'): 0.07307642256029055,
#   Timestamp('2026-09-30 00:00:00'): 0.5927559533980807,
#   Timestamp('2026-10-31 00:00:00'): -0.5920807543266717,
#   Timestamp('2026-11-30 00:00:00'): -1.6311376912876645,
#   Timestamp('2026-12-31 00:00:00'): 0.9070420845963935,
#   Timestamp('2027-01-31 00:00:00'): 1.4492432503661412,
#   Timestamp('2027-02-28 00:00:00'): -0.930114981021689,
#   Timestamp('2027-03-31 00:00:00'): 0.6058919729652751,
#   Timestamp('2027-04-30 00:00:00'): -0.45907525535911936,
#   Timestamp('2027-05-31 00:00:00'): -1.1168117435928144,
#   Timestamp('2056-06-30 00:00:00'): -1.32482560862335,
#   Timestamp('2056-07-31 00:00:00'): -0.040579984841897135,
#   Timestamp('2056-08-31 00:00:00'): -0.883925964810969,
#   Timestamp('2056-09-30 00:00:00'): -0.12617224068048188,
#   Timestamp('2056-10-31 00:00:00'): 0.5949060411150121,
#   Timestamp('2056-11-30 00:00:00'): -1.244476449456739,
#   Timestamp('2056-12-31 00:00:00'): 0.49434605633093975,
#   Timestamp('2057-01-31 00:00:00'): -0.5023874118390054,
#   Timestamp('2057-02-28 00:00:00'): -0.5671534510145103,
#   Timestamp('2057-03-31 00:00:00'): -1.3661771297114258,
#   Timestamp('2057-04-30 00:00:00'): 1.4251024347031807,
#   Timestamp('2057-05-31 00:00:00'): -0.6175457409385154,
#   Timestamp('2057-06-30 00:00:00'): -0.18482663869650745,
#   Timestamp('2057-07-31 00:00:00'): 0.9078945337409337,
#   Timestamp('2057-08-31 00:00:00'): -1.146593940669668,
#   Timestamp('2057-09-30 00:00:00'): -0.5875446695743304,
#   Timestamp('2057-10-31 00:00:00'): 1.6830881997763474,
#   Timestamp('2057-11-30 00:00:00'): 0.5590852289219885,
#   Timestamp('2057-12-31 00:00:00'): -0.6625852176592307,
#   Timestamp('2058-01-31 00:00:00'): -1.957638159131939,
#   Timestamp('2058-02-28 00:00:00'): -2.3013667160965756,
#   Timestamp('2058-03-31 00:00:00'): -0.3937565787388208,
#   Timestamp('2058-04-30 00:00:00'): -0.10396827950783019,
#   Timestamp('2058-05-31 00:00:00'): -0.28551103109753484,
#   Timestamp('2058-06-30 00:00:00'): -0.011564372257145432,
#   Timestamp('2058-07-31 00:00:00'): -0.07254740031026959,
#   Timestamp('2058-08-31 00:00:00'): -0.9141372953949569,
#   Timestamp('2058-09-30 00:00:00'): -0.029737771942890998,
#   Timestamp('2058-10-31 00:00:00'): -0.6010988256087569,
#   Timestamp('2058-11-30 00:00:00'): 0.2111550332577566,
#   Timestamp('2058-12-31 00:00:00'): 0.2572013677720788,
#   Timestamp('2059-01-31 00:00:00'): 1.5582905810055443,
#   Timestamp('2059-02-28 00:00:00'): -0.5941965177818886,
#   Timestamp('2059-03-31 00:00:00'): 1.2516630448718924,
#   Timestamp('2059-04-30 00:00:00'): -1.1000930241262392,
#   Timestamp('2059-05-31 00:00:00'): 0.6466347309708277,
#   Timestamp('2059-06-30 00:00:00'): -0.5807026443921344,
#   Timestamp('2059-07-31 00:00:00'): 2.157984019143335,
#   Timestamp('2059-08-31 00:00:00'): -1.5612976052497916,
#   Timestamp('2059-09-30 00:00:00'): 0.35313561332611726,
#   Timestamp('2059-10-31 00:00:00'): -1.730299566967499,
#   Timestamp('2059-11-30 00:00:00'): -0.8382418907908706,
#   Timestamp('2059-12-31 00:00:00'): 0.31945326291220455,
#   Timestamp('2060-01-31 00:00:00'): 0.5484997967316398,
#   Timestamp('2060-02-29 00:00:00'): 2.167196392361439,
#   Timestamp('2060-03-31 00:00:00'): -0.6212179594358047,
#   Timestamp('2060-04-30 00:00:00'): -1.464014895925334,
#   Timestamp('2060-05-31 00:00:00'): 0.1155758381303084,
#   Timestamp('2060-06-30 00:00:00'): -1.1505316593116584,
#   Timestamp('2060-07-31 00:00:00'): 0.6442375736816722,
#   Timestamp('2060-08-31 00:00:00'): 0.5171919993891309,
#   Timestamp('2060-09-30 00:00:00'): 1.493385370169371,
#   Timestamp('2060-10-31 00:00:00'): 2.8214163942623887,
#   Timestamp('2060-11-30 00:00:00'): -0.15432553584842973,
#   Timestamp('2060-12-31 00:00:00'): -0.734925470313436,
#   Timestamp('2061-01-31 00:00:00'): 0.6458012584492964,
#   Timestamp('2061-02-28 00:00:00'): 0.6357326228730441,
#   Timestamp('2061-03-31 00:00:00'): 0.5709182015281293,
#   Timestamp('2061-04-30 00:00:00'): -0.6598348384939287,
#   Timestamp('2061-05-31 00:00:00'): 1.3973153098782802,
#   Timestamp('2061-06-30 00:00:00'): 0.5878157580234307,
#   Timestamp('2061-07-31 00:00:00'): -0.7791776502003541,
#   Timestamp('2061-08-31 00:00:00'): 1.0870795745704342,
#   Timestamp('2061-09-30 00:00:00'): 1.5912418610193937,
#   Timestamp('2061-10-31 00:00:00'): 0.8254530650070755,
#   Timestamp('2061-11-30 00:00:00'): -0.9491952508700822,
#   Timestamp('2061-12-31 00:00:00'): 0.2189436062991575}}

# %%
df.to_json('test_df_to.json')

# %%
df.to_csv('test_df_to.csv', index=False)

# %%
num_arr.tolist()
# Out:
# [[-0.31141236301659725,
#   0.6672081549258488,
#   1.717705577810777,
#   -1.847369249602086],
#  [0.24880839036409702,
#   0.04466423042135691,
#   0.6252717370432854,
#   1.7308534073508526],
#  [0.8045776741791452,
#   -0.08150251970000674,
#   0.5532591421611422,
#   -0.26237724572934956],
#  [0.47656882150960644,
#   -1.458649008780931,
#   -1.1717204452748284,
#   -1.7735153177457166],
#  [-0.0014782057329237718,
#   -0.9963074681185808,
#   0.36736999245223817,
#   0.1400013115859814],
#  [1.5850820616986345,
#   0.06739843899428061,
#   0.1491002517080361,
#   1.2365299860546946],
#  [0.6060252812910359,
#   0.28840673683876106,
#   0.004997279011274257,
#   1.2087177815366],
#  [-1.78362879448501,
#   -0.6923941603304775,
#   -1.2531291612175828,
#   0.47250816535697093],
#  [0.4692478912799219,
#   -1.1745042208744816,
#   0.19842787651696367,
#   -0.30837899677364783],
#  [0.5751684025563769,
#   -0.3379262089334958,
#   0.37860739263839055,
#   1.5496860242356907],
#  [-0.2579318089378089,
#   -1.8697896744279086,
#   0.07563523560401077,
#   -0.8107160003442901],
#  [-0.7065097335002044,
#   -0.06807541093184333,
#   2.8748753043570354,
#   0.2847781739296784],
#  [0.06222924490621912,
#   -0.8981268153802197,
#   -0.0514270359019157,
#   1.0777876886047066],
#  [0.1523407260175863,
#   -0.40038089744020244,
#   -1.2879394989274395,
#   0.21301128688792725],
#  [1.7570024152267363,
#   0.9327320814244686,
#   0.3661390495883998,
#   1.9033117521643892],
#  [-1.1616086920487436,
#   -0.6892155713291694,
#   -0.6913943791870377,
#   1.8794970752865758,
#   0.5709182015281293],
#  [0.09117171289562771,
#   -0.6337358681552533,
#   -0.7459195601844529,
#   -0.6598348384939287],
#  [-2.060853409294118,
#   -0.3164401375928491,
#   -0.32491591989969987,
#   1.3973153098782802],
#  [0.27039308230111986,
#   -1.4693250081173006,
#   1.1970169213310822,
#   0.5878157580234307],
#  [0.26855294819468106,
#   -0.6015716275865839,
#   -2.0803171358068613,
#   -0.7791776502003541],
#  [0.31479877065357387,
#   -0.08263519797142008,
#   -0.24939933872039066,
#   1.0870795745704342],
#  [-2.0129533490870246,
#   0.6012052929306103,
#   -1.1775530540205876,
#   1.5912418610193937],
#  [-1.242894228495278,
#   -1.3315630787381754,
#   -0.7626549983040171,
#   0.8254530650070755],
#  [-1.1929098398437916,
#   0.32982011963542657,
#   -0.18162357499219675,
#   -0.9491952508700822],
#  [0.8782949386402087,
#   -0.039897138937627405,
#   0.8692473593594384,
#   0.2189436062991575]]

# %% [markdown]
# Обратите внимание, что эта операция может занять много времени, если ваш `DataFrame` имеет столбцы с разными типами данных, что сводится к фундаментальному различию между pandas и `NumPy`: массивы `NumPy` имеют один тип данных для всего массива, тогда как `DataFrames` в pandas имеет один тип данных для каждого столбца. Когда вы вызываете `DataFrame.to_numpy()`, pandas определит тип данных `NumPy`, который может содержать все типы данных `DataFrame`. Этот тип данных может в конечном итоге оказаться объектом (`object`, т.е. строкой), что потребует приведения каждого значения к объекту Python.
#
# Наш `DataFrame` содержит значения с плавающей точкой, поэтому `DataFrame.to_numpy()` сработает быстро и не требует копирования данных.

# %% [markdown]
# Для df2, который содержит несколько типов данных, вызов `DataFrame.to_numpy()` является относительно дорогостоящим:

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'red', 'foobar'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'green', 'foobar'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'blue', 'foobar'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'red', 'foobar']],
#       dtype=object)

# %% [markdown]
# Транспонируем данные:

# %%
df_copy = df.T

# %%
df_copy
# Out:
#    2012-01-31  2012-02-29  2012-03-31  2012-04-30  2012-05-31  2012-06-30  \
# A   -0.311412    0.248808    0.804578    0.476569   -0.001478    1.585082
# B    0.667208    0.044664   -0.081503   -1.458649   -0.996307    0.067398
# C    1.717706    0.625272    0.553259   -1.171720    0.367370    0.149100
# D   -1.847369    1.730853   -0.262377   -1.773515    0.140001    1.236530
#
#    2012-07-31  2012-08-31  2012-09-30  2012-10-31  ...  2061-03-31  \
# A    0.606025   -1.783629    0.469248    0.575168  ...    1.760953
# B    0.288407   -0.692394   -1.174504   -0.337926  ...    1.026578
# C    0.004997   -1.253129    0.198428    0.378607  ...    1.879497
# D    1.208718    0.472508   -0.308379    1.549686  ...    0.570918
#
#    2061-04-30  2061-05-31  2061-06-30  2061-07-31  2061-08-31  2061-09-30  \
# A    0.091172   -2.060853    0.270393    0.268553    0.314799   -2.012953
# B   -0.633736   -0.316440   -1.469325   -0.601572   -0.082635    0.601205
# C   -0.745920   -0.324916    1.197017   -2.080317   -0.249399   -1.177553
# D   -0.659835    1.397315    0.587816   -0.779178    1.087080    1.591242
#
#    2061-10-31  2061-11-30  2061-12-31
# A   -1.242894   -1.192910    0.878295
# B   -1.331563    0.329820   -0.039897
# C   -0.762655   -0.181624    0.869247
# D    0.825453   -0.949195    0.218944
#
# [4 rows x 600 columns]

# %%
df_copy
# Out:
#    2012-01-31  2012-02-29  2012-03-31  2012-04-30  2012-05-31  2012-06-30  \
# A   -0.311412    0.248808    0.804578    0.476569   -0.001478    1.585082
# B    0.667208    0.044664   -0.081503   -1.458649   -0.996307    0.067398
# C    1.717706    0.625272    0.553259   -1.171720    0.367370    0.149100
# D   -1.847369    1.730853   -0.262377   -1.773515    0.140001    1.236530
#
#    2012-07-31  2012-08-31  2012-09-30  2012-10-31  ...  2061-03-31  \
# A    0.606025   -1.783629    0.469248    0.575168  ...    1.760953
# B    0.288407   -0.692394   -1.174504   -0.337926  ...    1.026578
# C    0.004997   -1.253129    0.198428    0.378607  ...    1.879497
# D    1.208718    0.472508   -0.308379    1.549686  ...    0.570918
#
#    2061-04-30  2061-05-31  2061-06-30  2061-07-31  2061-08-31  2061-09-30  \
# A    0.091172   -2.060853    0.270393    0.268553    0.314799   -2.012953
# B   -0.633736   -0.316440   -1.469325   -0.601572   -0.082635    0.601205
# C   -0.745920   -0.324916    1.197017   -2.080317   -0.249399   -1.177553
# D   -0.659835    1.397315    0.587816   -0.779178    1.087080    1.591242
#
#    2061-10-31  2061-11-30  2061-12-31
# A   -1.242894   -1.192910    0.878295
# B   -1.331563    0.329820   -0.039897
# C   -0.762655   -0.181624    0.869247
# D    0.825453   -0.949195    0.218944
#
# [4 rows x 600 columns]

# %% [markdown]
# Сортировка по столбцам, см. [`sort_index()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_index.html):

# %%
df.sort_index(axis=0, ascending=False) # по умолчанию axis=0, т.е. сортировка по строкам
# Out:
#                    A         B         C         D
# 2061-12-31  0.878295 -0.039897  0.869247  0.218944
# 2061-11-30 -1.192910  0.329820 -0.181624 -0.949195
# 2061-10-31 -1.242894 -1.331563 -0.762655  0.825453
# 2061-09-30 -2.012953  0.601205 -1.177553  1.591242
# 2061-08-31  0.314799 -0.082635 -0.249399  1.087080
# ...              ...       ...       ...       ...
# 2012-05-31 -0.001478 -0.996307  0.367370  0.140001
# 2012-04-30  0.476569 -1.458649 -1.171720 -1.773515
# 2012-03-31  0.804578 -0.081503  0.553259 -0.262377
# 2012-02-29  0.248808  0.044664  0.625272  1.730853
# 2012-01-31 -0.311412  0.667208  1.717706 -1.847369
#
# [600 rows x 4 columns]

# %% [markdown]
# Сортировка по значениям, см. [`sort_values()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html#pandas.DataFrame.sort_values):

# %%
df.sort_values(by=['A','C']) # по умолчанию сортировка по индексу, выбрали столбец 'B'
# Out:
#                    A         B         C         D
# 2017-12-31 -3.886403 -1.466020 -0.022690  0.593622
# 2043-09-30 -2.826097 -0.772263  0.308189 -0.275274
# 2042-10-31 -2.642154 -1.231598  1.137054 -0.240391
# 2037-04-30 -2.527121  0.672354 -1.507424  0.306174
# 2029-07-31 -2.236027 -0.049455  1.161386 -0.361761
# ...              ...       ...       ...       ...
# 2013-10-31  2.439012 -2.041659 -0.169398  1.065935
# 2025-12-31  2.593098  0.615974 -0.905918  0.203194
# 2050-06-30  2.735801 -1.415964 -0.199138 -0.201553
# 2025-03-31  2.746208  0.023216  0.689347  0.062712
# 2048-02-29  3.106999 -0.525790 -0.998607 -1.610760
#
# [600 rows x 4 columns]

# %% [markdown]
# ## Выбор элементов

# %% [markdown]
# Рекомендуем использовать оптимизированные методы pandas для доступа к данным:  `.ix`, `.loc` и `.iloc`.

# %% [markdown]
# ### Получение

# %% [markdown]
# Выбор столбца, который возвращает [`Series`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html#pandas.Series), эквивалентно `df.A`:

# %%
df['A']
# Out:
# 2012-01-31   -0.311412
# 2012-02-29    0.248808
# 2012-03-31    0.804578
# 2012-04-30    0.476569
# 2012-05-31   -0.001478
#                 ...
# 2061-08-31    0.314799
# 2061-09-30   -2.012953
# 2061-10-31   -1.242894
# 2061-11-30   -1.192910
# 2061-12-31    0.878295
# Freq: ME, Name: A, Length: 600, dtype: float64

# %% [markdown]
# Выбор с помощью `[ ]`, вырезает строки:

# %%
df[:'2013-04-30']
# Out:
#                    A         B         C         D
# 2012-01-31 -0.311412  0.667208  1.717706 -1.847369
# 2012-02-29  0.248808  0.044664  0.625272  1.730853
# 2012-03-31  0.804578 -0.081503  0.553259 -0.262377
# 2012-04-30  0.476569 -1.458649 -1.171720 -1.773515
# 2012-05-31 -0.001478 -0.996307  0.367370  0.140001
# 2012-06-30  1.585082  0.067398  0.149100  1.236530
# 2012-07-31  0.606025  0.288407  0.004997  1.208718
# 2012-08-31 -1.783629 -0.692394 -1.253129  0.472508
# 2012-09-30  0.469248 -1.174504  0.198428 -0.308379
# 2012-10-31  0.575168 -0.337926  0.378607  1.549686
# 2012-11-30 -0.257932 -1.869790  0.075635 -0.810716
# 2012-12-31 -0.706510 -0.068075  2.874875  0.284778
# 2013-01-31  0.062229 -0.898127 -0.051427  1.077788
# 2013-02-28  0.152341 -0.400381 -1.287939  0.213011
# 2013-03-31  1.757002  0.932732  0.366139  1.903312
# 2013-04-30 -1.161609 -0.689216 -0.691394 -0.968044

# %%
df['2013-01-02':'2013-02-03']
# Out:
#                    A         B         C         D
# 2013-01-31  0.062229 -0.898127 -0.051427  1.077788

# %% [markdown]
# ### Выбор по метке

# %% [markdown]
# Подробнее см. в [Документации](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#indexing-label)

# %% [markdown]
# Для получения строки с помощью метки:

# %%
df.loc['2013-11-30','A'] # метка индекса Timestamp('2013-01-01 00:00:00', freq='D')
# Out:
# np.float64(-0.5147734294564702)

# %%
df.loc['2013-11-30','A'] = 10.30 # переприсваивание объекта к срезу

# %%
df.loc['2013-11-30','A']
# Out:
# np.float64(10.3)

# %%
df[df['A'] == np.float64(10.3)] # ячейка поменяла значения (не делать, если не необходимо)
# Out:
#                A         B        C         D
# 2013-11-30  10.3 -1.057012 -0.23714  1.216853

# %% [markdown]
# Выбор по нескольким осям:

# %%
df.loc['2013-11-30', ['A', 'B']]
# Out:
# A   -0.514773
# B   -1.057012
# Name: 2013-11-30 00:00:00, dtype: float64

# %% [markdown]
# При отображении срезов меток включаются обе конечные точки:

# %%
df.loc['2013-01-02':'2014-01-04', ['C', 'B']]
# Out:
#                    C         B
# 2013-01-31 -0.051427 -0.898127
# 2013-02-28 -1.287939 -0.400381
# 2013-03-31  0.366139  0.932732
# 2013-04-30 -0.691394 -0.689216
# 2013-05-31  0.477091  0.842597
# 2013-06-30  1.355888 -1.369857
# 2013-07-31 -0.486616 -1.731272
# 2013-08-31  0.965656  1.520072
# 2013-09-30 -0.825309 -0.899919
# 2013-10-31 -0.169398 -2.041659
# 2013-11-30 -0.237140 -1.057012
# 2013-12-31  0.900067 -0.547614

# %% [markdown]
# Для получения скалярного значения:

# %%
df.at[dates[3], 'A'] #одиночное значение по индексу
# Out:
# np.float64(0.47656882150960644)

# %% [markdown]
# ### Выбор по позиции

# %% [markdown]
# Подробнее см. в [Документации](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#indexing-integer)

# %% [markdown]
# Выбор позиции с помощью целых чисел:

# %%
df
# Out:
#                    A         B         C         D
# 2012-01-31 -0.311412  0.667208  1.717706 -1.847369
# 2012-02-29  0.248808  0.044664  0.625272  1.730853
# 2012-03-31  0.804578 -0.081503  0.553259 -0.262377
# 2012-04-30  0.476569 -1.458649 -1.171720 -1.773515
# 2012-05-31 -0.001478 -0.996307  0.367370  0.140001
# ...              ...       ...       ...       ...
# 2061-08-31  0.314799 -0.082635 -0.249399  1.087080
# 2061-09-30 -2.012953  0.601205 -1.177553  1.591242
# 2061-10-31 -1.242894 -1.331563 -0.762655  0.825453
# 2061-11-30 -1.192910  0.329820 -0.181624 -0.949195
# 2061-12-31  0.878295 -0.039897  0.869247  0.218944
#
# [600 rows x 4 columns]

# %%
df.iloc[1]
# Out:
# A    0.248808
# B    0.044664
# C    0.625272
# D    1.730853
# Name: 2012-02-29 00:00:00, dtype: float64

# %% [markdown]
# По целочисленным срезам, действующим аналогично NumPy / Python, т.е. правое граничное значение не включается:

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2012-04-30  0.476569 -1.458649
# 2012-05-31 -0.001478 -0.996307

# %% [markdown]
# По спискам целочисленных позиций, аналогично стилю NumPy / Python:

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2012-02-29  0.248808  0.625272
# 2012-03-31  0.804578  0.553259
# 2012-05-31 -0.001478  0.367370

# %% [markdown]
# Для явного создания среза строк:

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2012-02-29  0.248808  0.044664  0.625272  1.730853
# 2012-03-31  0.804578 -0.081503  0.553259 -0.262377

# %% [markdown]
# Для явного создания среза столбцов:

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2012-01-31  0.667208  1.717706
# 2012-02-29  0.044664  0.625272
# 2012-03-31 -0.081503  0.553259
# 2012-04-30 -1.458649 -1.171720
# 2012-05-31 -0.996307  0.367370
# ...              ...       ...
# 2061-08-31 -0.082635 -0.249399
# 2061-09-30  0.601205 -1.177553
# 2061-10-31 -1.331563 -0.762655
# 2061-11-30  0.329820 -0.181624
# 2061-12-31 -0.039897  0.869247
#
# [600 rows x 2 columns]

# %% [markdown]
# Для явного получения значений:

# %%
df.iloc[1, 1]
# Out:
# np.float64(0.04466423042135691)

# %% [markdown]
# Для получения быстрого доступа к скаляру (эквивалентно предыдущему методу):

# %%
df.iat[1, 1]
# Out:
# np.float64(0.04466423042135691)

# %% [markdown]
# ### Булево индексирование

# %% [markdown]
# Использование значений столбца для выбора данных:

# %%
df[(df['A'] > 0) | (df['B'] > 0) & ( df['C'] < 0)]
# Out:
#                    A         B         C         D
# 2012-02-29  0.248808  0.044664  0.625272  1.730853
# 2012-03-31  0.804578 -0.081503  0.553259 -0.262377
# 2012-04-30  0.476569 -1.458649 -1.171720 -1.773515
# 2012-06-30  1.585082  0.067398  0.149100  1.236530
# 2012-07-31  0.606025  0.288407  0.004997  1.208718
# ...              ...       ...       ...       ...
# 2061-07-31  0.268553 -0.601572 -2.080317 -0.779178
# 2061-08-31  0.314799 -0.082635 -0.249399  1.087080
# 2061-09-30 -2.012953  0.601205 -1.177553  1.591242
# 2061-11-30 -1.192910  0.329820 -0.181624 -0.949195
# 2061-12-31  0.878295 -0.039897  0.869247  0.218944
#
# [389 rows x 4 columns]

# %% [markdown]
# Выбор значений из `DataFrame`, для которых выполняется логическое условие:

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2012-01-31       NaN  0.667208  1.717706       NaN
# 2012-02-29  0.248808  0.044664  0.625272  1.730853
# 2012-03-31  0.804578       NaN  0.553259       NaN
# 2012-04-30  0.476569       NaN       NaN       NaN
# 2012-05-31       NaN       NaN  0.367370  0.140001
# ...              ...       ...       ...       ...
# 2061-08-31  0.314799       NaN       NaN  1.087080
# 2061-09-30       NaN  0.601205       NaN  1.591242
# 2061-10-31       NaN       NaN       NaN  0.825453
# 2061-11-30       NaN  0.329820       NaN       NaN
# 2061-12-31  0.878295       NaN  0.869247  0.218944
#
# [600 rows x 4 columns]

# %% [markdown]
# Использование метода [`isin()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.isin.html#pandas.Series.isin) для фильтрации:

# %%
df2
# Out:
#      A          B    C  D      E       F
# 0  1.0 2013-01-02  1.0  3    red  foobar
# 1  1.0 2013-01-02  1.0  3  green  foobar
# 2  1.0 2013-01-02  1.0  3   blue  foobar
# 3  1.0 2013-01-02  1.0  3    red  foobar

# %%
df2['E'].isin(['green', 'blue'])
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: E, dtype: bool

# %%
~df2['E'].isin(['green', 'blue'])
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# Name: E, dtype: bool

# %%
df2[~df2['E'].isin(['green', 'blue'])] # фильтруем
# Out:
#      A          B    C  D    E       F
# 0  1.0 2013-01-02  1.0  3  red  foobar
# 3  1.0 2013-01-02  1.0  3  red  foobar

# %% [markdown]
# ## Изменение / добавление значений

# %%
df['E'] = ['one', 'one', 'two', 'three', 'four', 'three']*100 # добавляем столбец
df
# Out:
#                    A         B         C         D      E
# 2013-01-31 -2.065810  0.500734  0.363846  0.066299    one
# 2013-02-28  0.348288 -1.535217 -0.211007 -0.091686    one
# 2013-03-31  0.508579 -1.424744  1.767825  1.360248    two
# 2013-04-30 -0.576584 -0.529803  0.251141  0.094734  three
# 2013-05-31  0.192248  1.020445  0.812392  0.351854   four
# ...              ...       ...       ...       ...    ...
# 2062-08-31 -0.922229  2.214785  1.755481 -1.343570    one
# 2062-09-30 -0.353849 -0.170232  0.114496  0.495401    two
# 2062-10-31 -2.533816 -0.057073  0.021984 -0.759623  three
# 2062-11-30  2.399247 -0.729486 -0.135819 -1.375543   four
# 2062-12-31  0.635386 -0.249315  0.981285 -1.633425  three
#
# [600 rows x 5 columns]

# %% [markdown]
# При добавлении нового столбца данные автоматически выравниваются по индексам:

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130228', periods=6,freq='M'))
s1
# Out:
# 2013-02-28    1
# 2013-03-31    2
# 2013-04-30    3
# 2013-05-31    4
# 2013-06-30    5
# 2013-07-31    6
# Freq: M, dtype: int64

# %%
df['F'] = s1 # отсутствующие значения после выравнивания заменились NaN
df
# Out:
#                    A         B         C         D      E    F
# 2013-01-31 -2.065810  0.500734  0.363846  0.066299    one  NaN
# 2013-02-28  0.348288 -1.535217 -0.211007 -0.091686    one  1.0
# 2013-03-31  0.508579 -1.424744  1.767825  1.360248    two  2.0
# 2013-04-30 -0.576584 -0.529803  0.251141  0.094734  three  3.0
# 2013-05-31  0.192248  1.020445  0.812392  0.351854   four  4.0
# ...              ...       ...       ...       ...    ...  ...
# 2062-08-31 -0.922229  2.214785  1.755481 -1.343570    one  NaN
# 2062-09-30 -0.353849 -0.170232  0.114496  0.495401    two  NaN
# 2062-10-31 -2.533816 -0.057073  0.021984 -0.759623  three  NaN
# 2062-11-30  2.399247 -0.729486 -0.135819 -1.375543   four  NaN
# 2062-12-31  0.635386 -0.249315  0.981285 -1.633425  three  NaN
#
# [600 rows x 6 columns]

# %% [markdown]
# Установка значений по метке:

# %%
df.iat[0, 1] = 0
df
# Out:
#                    A         B         C         D      E    F
# 2013-01-31 -2.065810  0.000000  0.363846  0.066299    one  NaN
# 2013-02-28  0.348288 -1.535217 -0.211007 -0.091686    one  1.0
# 2013-03-31  0.508579 -1.424744  1.767825  1.360248    two  2.0
# 2013-04-30 -0.576584 -0.529803  0.251141  0.094734  three  3.0
# 2013-05-31  0.192248  1.020445  0.812392  0.351854   four  4.0
# ...              ...       ...       ...       ...    ...  ...
# 2062-08-31 -0.922229  2.214785  1.755481 -1.343570    one  NaN
# 2062-09-30 -0.353849 -0.170232  0.114496  0.495401    two  NaN
# 2062-10-31 -2.533816 -0.057073  0.021984 -0.759623  three  NaN
# 2062-11-30  2.399247 -0.729486 -0.135819 -1.375543   four  NaN
# 2062-12-31  0.635386 -0.249315  0.981285 -1.633425  three  NaN
#
# [600 rows x 6 columns]

# %%
df.loc['2013-01-31', 'D'] = 111
df
# Out:
#                    A         B         C           D      E    F
# 2013-01-31 -2.065810  0.000000  0.363846  111.000000    one  NaN
# 2013-02-28  0.348288 -1.535217 -0.211007   -0.091686    one  1.0
# 2013-03-31  0.508579 -1.424744  1.767825    1.360248    two  2.0
# 2013-04-30 -0.576584 -0.529803  0.251141    0.094734  three  3.0
# 2013-05-31  0.192248  1.020445  0.812392    0.351854   four  4.0
# ...              ...       ...       ...         ...    ...  ...
# 2062-08-31 -0.922229  2.214785  1.755481   -1.343570    one  NaN
# 2062-09-30 -0.353849 -0.170232  0.114496    0.495401    two  NaN
# 2062-10-31 -2.533816 -0.057073  0.021984   -0.759623  three  NaN
# 2062-11-30  2.399247 -0.729486 -0.135819   -1.375543   four  NaN
# 2062-12-31  0.635386 -0.249315  0.981285   -1.633425  three  NaN
#
# [600 rows x 6 columns]

# %% [markdown]
# Установка значений путем присвоения массива NumPy:

# %%
df['G'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C           D      E    F  G
# 2013-01-31 -2.065810  0.000000  0.363846  111.000000    one  NaN  5
# 2013-02-28  0.348288 -1.535217 -0.211007   -0.091686    one  1.0  5
# 2013-03-31  0.508579 -1.424744  1.767825    1.360248    two  2.0  5
# 2013-04-30 -0.576584 -0.529803  0.251141    0.094734  three  3.0  5
# 2013-05-31  0.192248  1.020445  0.812392    0.351854   four  4.0  5
# ...              ...       ...       ...         ...    ...  ... ..
# 2062-08-31 -0.922229  2.214785  1.755481   -1.343570    one  NaN  5
# 2062-09-30 -0.353849 -0.170232  0.114496    0.495401    two  NaN  5
# 2062-10-31 -2.533816 -0.057073  0.021984   -0.759623  three  NaN  5
# 2062-11-30  2.399247 -0.729486 -0.135819   -1.375543   four  NaN  5
# 2062-12-31  0.635386 -0.249315  0.981285   -1.633425  three  NaN  5
#
# [600 rows x 7 columns]

# %%
df_numeric = df._get_numeric_data()
df_numeric[df_numeric > 0] = -df_numeric # все положительные превращаем в отрицательные
df_numeric
# Out:
#                    A         B         C           D    F  G
# 2013-01-31 -2.065810  0.000000 -0.363846 -111.000000  NaN -5
# 2013-02-28 -0.348288 -1.535217 -0.211007   -0.091686 -1.0 -5
# 2013-03-31 -0.508579 -1.424744 -1.767825   -1.360248 -2.0 -5
# 2013-04-30 -0.576584 -0.529803 -0.251141   -0.094734 -3.0 -5
# 2013-05-31 -0.192248 -1.020445 -0.812392   -0.351854 -4.0 -5
# ...              ...       ...       ...         ...  ... ..
# 2062-08-31 -0.922229 -2.214785 -1.755481   -1.343570  NaN -5
# 2062-09-30 -0.353849 -0.170232 -0.114496   -0.495401  NaN -5
# 2062-10-31 -2.533816 -0.057073 -0.021984   -0.759623  NaN -5
# 2062-11-30 -2.399247 -0.729486 -0.135819   -1.375543  NaN -5
# 2062-12-31 -0.635386 -0.249315 -0.981285   -1.633425  NaN -5
#
# [600 rows x 6 columns]

# %%
np.sin(df_numeric)
# Out:
#                    A         B         C         D         F         G
# 2013-01-31 -0.879962  0.000000 -0.355871  0.864551       NaN  0.958924
# 2013-02-28 -0.341289 -0.999367 -0.209444 -0.091558 -0.841471  0.958924
# 2013-03-31 -0.486937 -0.989353 -0.980653 -0.977916 -0.909297  0.958924
# 2013-04-30 -0.545163 -0.505364 -0.248509 -0.094592 -0.141120  0.958924
# 2013-05-31 -0.191066 -0.852341 -0.725934 -0.344638  0.756802  0.958924
# ...              ...       ...       ...       ...       ...       ...
# 2062-08-31 -0.796950 -0.799707 -0.982994 -0.974295       NaN  0.958924
# 2062-09-30 -0.346511 -0.169411 -0.114246 -0.475385       NaN  0.958924
# 2062-10-31 -0.571044 -0.057042 -0.021982 -0.688648       NaN  0.958924
# 2062-11-30 -0.676018 -0.666487 -0.135402 -0.980999       NaN  0.958924
# 2062-12-31 -0.593488 -0.246740 -0.831213 -0.998039       NaN  0.958924
#
# [600 rows x 6 columns]

# %% [markdown]
# ### Применение функций к данным (apply)

# %% [markdown]
# Метод apply() — это инструмент для преобразования объекта DataFrame, его можно применять как к одному столбцу, так и к нескольким.

# %%
# Функция numpy.cumsum() возвращает кумулятивную сумму элементов по заданной оси
df[['A', 'B']].apply(np.cumsum)
# Out:
#                      A           B
# 2013-01-31   -2.065810    0.000000
# 2013-02-28   -2.414098   -1.535217
# 2013-03-31   -2.922677   -2.959962
# 2013-04-30   -3.499261   -3.489765
# 2013-05-31   -3.691509   -4.510210
# ...                ...         ...
# 2062-08-31 -505.031380 -452.881064
# 2062-09-30 -505.385229 -453.051296
# 2062-10-31 -507.919045 -453.108369
# 2062-11-30 -510.318292 -453.837855
# 2062-12-31 -510.953678 -454.087170
#
# [600 rows x 2 columns]

# %% [markdown]
# Можно применить лямбда-функции, которые полезны в том случае, когда нужна одноразовая функция. Такие функции еще называют анонимными.
#
# `lambda arguments: expression`

# %%
df_numeric.apply(lambda x: x.max() - x.min())
# Out:
# A      3.165183
# B      2.845246
# C      3.461340
# D    110.999821
# F      5.000000
# G      0.000000
# dtype: float64

# %% [markdown]
# ### Строковые методы

# %% [markdown]
# Series оснащен набором методов в атрибуте `str` для обработки строк, которые упрощают работу с каждым элементом массива, подробнее см. в [Документации](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#text-string-methods).

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: object

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
s.str.upper()
# Out:
# 0       A
# 1       B
# 2       C
# 3    AABA
# 4    BACA
# 5     NaN
# 6    CABA
# 7     DOG
# 8     CAT
# dtype: object

# %% [markdown]
# ## Обработка пропусков в данных

# %% [markdown]
# pandas в основном использует значение [`np.nan`](https://numpy.org/doc/stable/user/misc.html) для представления отсутствующих данных. По умолчанию они не включается в вычисления, см. подробнее в [Документации](https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html#missing-data)

# %% [markdown]
# ### Обнаружение пропусков

# %% [markdown]
# Метод `info()` соотносит максимальное количество записей в датафрейме с количеством записей в каждом столбце:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 600 entries, 2013-01-31 to 2062-12-31
# Freq: M
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       600 non-null    float64
#  1   B       600 non-null    float64
#  2   C       600 non-null    float64
#  3   D       600 non-null    float64
#  4   E       600 non-null    object
#  5   F       6 non-null      float64
#  6   G       600 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 53.7+ KB

# %% [markdown]
# Можно последовательно использовать методы `isna()` и `sum()`:

# %%
# .isna() выдает True или 1, если есть пропуск, .sum() суммирует единицы по столбцам
df.isna().sum()
# Out:
# A      0
# B      0
# C      0
# D      0
# E      0
# F    594
# G      0
# dtype: int64

# %% [markdown]
# Также не сложно посчитать процент пропущенных значений:

# %%
# для этого разделим сумму пропусков в каждом столбце на количество наблюдений,
# округлим результат и умножим его на 100
df.isna().sum() / len(df.round(4)) * 100
# Out:
# A     0.0
# B     0.0
# C     0.0
# D     0.0
# E     0.0
# F    99.0
# G     0.0
# dtype: float64

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# Чтобы удалить строки, в которых отсутствуют данные, см. [`dropna()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html):

# %%
df.dropna() # how='any', axis=0 по умолчанию, т.е. удаляются все строки с пропущенными данными
# Out:
#                    A         B         C         D      E    F  G
# 2013-02-28 -0.348288 -1.535217 -0.211007 -0.091686    one -1.0 -5
# 2013-03-31 -0.508579 -1.424744 -1.767825 -1.360248    two -2.0 -5
# 2013-04-30 -0.576584 -0.529803 -0.251141 -0.094734  three -3.0 -5
# 2013-05-31 -0.192248 -1.020445 -0.812392 -0.351854   four -4.0 -5
# 2013-06-30 -1.509585 -0.730217 -0.730922 -0.148052  three -5.0 -5
# 2013-07-31 -0.928314 -1.522277 -0.608694 -0.389239    one -6.0 -5

# %% [markdown]
# Если в одном из столбцов большой процент пропусков, построчное удаление просто оставит нас без данных. В этом случае, если мы выбираем стратегию удаления данных, разумнее удалить сам столбец.

# %%
# передадим в параметр columns тот столбец, который хотим удалить
df.drop(columns = ['F'])
# Out:
#                    A         B         C           D      E  G
# 2013-01-31 -2.065810  0.000000 -0.363846 -111.000000    one -5
# 2013-02-28 -0.348288 -1.535217 -0.211007   -0.091686    one -5
# 2013-03-31 -0.508579 -1.424744 -1.767825   -1.360248    two -5
# 2013-04-30 -0.576584 -0.529803 -0.251141   -0.094734  three -5
# 2013-05-31 -0.192248 -1.020445 -0.812392   -0.351854   four -5
# ...              ...       ...       ...         ...    ... ..
# 2062-08-31 -0.922229 -2.214785 -1.755481   -1.343570    one -5
# 2062-09-30 -0.353849 -0.170232 -0.114496   -0.495401    two -5
# 2062-10-31 -2.533816 -0.057073 -0.021984   -0.759623  three -5
# 2062-11-30 -2.399247 -0.729486 -0.135819   -1.375543   four -5
# 2062-12-31 -0.635386 -0.249315 -0.981285   -1.633425  three -5
#
# [600 rows x 6 columns]

# %% [markdown]
# ### Заполнение пропусков

# %% [markdown]
# Пропуски в числовых признаках можно заполнить средним арифметическим или медианой:

# %%
df.head(10)
# Out:
#                    A         B         C           D      E    F  G
# 2013-01-31 -2.065810  0.000000 -0.363846 -111.000000    one  NaN -5
# 2013-02-28 -0.348288 -1.535217 -0.211007   -0.091686    one -1.0 -5
# 2013-03-31 -0.508579 -1.424744 -1.767825   -1.360248    two -2.0 -5
# 2013-04-30 -0.576584 -0.529803 -0.251141   -0.094734  three -3.0 -5
# 2013-05-31 -0.192248 -1.020445 -0.812392   -0.351854   four -4.0 -5
# 2013-06-30 -1.509585 -0.730217 -0.730922   -0.148052  three -5.0 -5
# 2013-07-31 -0.928314 -1.522277 -0.608694   -0.389239    one -6.0 -5
# 2013-08-31 -0.879384 -1.607191 -1.247258   -0.485029    one  NaN -5
# 2013-09-30 -0.495681 -0.162004 -0.760876   -0.232103    two  NaN -5
# 2013-10-31 -0.320099 -0.499259 -0.433996   -1.191528  three  NaN -5

# %%
# сделаем копию датафрейма
fillna_median = df.copy()

# заполним пропуски в столбце F медианным значением,
# можно заполнить и средним арифметическим через метод .mean()
fillna_median.F.fillna(fillna_median.F.median(), inplace = True)

# убедимся, что пропусков не осталось
fillna_median.F.isna().sum()
# Out:
# 0

# %% [markdown]
# У такого простого и понятного подхода тем не менее есть ряд недостатков:
#
# - когда в данных появляется большое количество одинаковых близких к среднему значений, мы снижаем ценную вариативность в данных;
# - кроме того, такое заполнение пропусков может быть некорректно. Например, если заполнить пропуски в столбце «Стаж» средним значением или медианой, молодой сотрудник может получить больший стаж, чем у него есть на самом деле, а сотрудник в возрасте, меньший.

# %% [markdown]
# Также популярно заполнение значениями из предшествующей (аргумент method='bfill') либо последующей записи (method='ffill'):

# %%
df.fillna(method='bfill')
# Out:
#                    A         B         C           D      E    F  G
# 2013-01-31 -2.065810  0.000000 -0.363846 -111.000000    one -1.0 -5
# 2013-02-28 -0.348288 -1.535217 -0.211007   -0.091686    one -1.0 -5
# 2013-03-31 -0.508579 -1.424744 -1.767825   -1.360248    two -2.0 -5
# 2013-04-30 -0.576584 -0.529803 -0.251141   -0.094734  three -3.0 -5
# 2013-05-31 -0.192248 -1.020445 -0.812392   -0.351854   four -4.0 -5
# ...              ...       ...       ...         ...    ...  ... ..
# 2062-08-31 -0.922229 -2.214785 -1.755481   -1.343570    one  NaN -5
# 2062-09-30 -0.353849 -0.170232 -0.114496   -0.495401    two  NaN -5
# 2062-10-31 -2.533816 -0.057073 -0.021984   -0.759623  three  NaN -5
# 2062-11-30 -2.399247 -0.729486 -0.135819   -1.375543   four  NaN -5
# 2062-12-31 -0.635386 -0.249315 -0.981285   -1.633425  three  NaN -5
#
# [600 rows x 7 columns]

# %% [markdown]
# Следует отметить, что для аналогичных действий имеются специальные методы с названиями bfill и ffill:

# %%
df.ffill()
# Out:
#                    A         B         C           D      E    F  G
# 2013-01-31 -2.065810  0.000000 -0.363846 -111.000000    one  NaN -5
# 2013-02-28 -0.348288 -1.535217 -0.211007   -0.091686    one -1.0 -5
# 2013-03-31 -0.508579 -1.424744 -1.767825   -1.360248    two -2.0 -5
# 2013-04-30 -0.576584 -0.529803 -0.251141   -0.094734  three -3.0 -5
# 2013-05-31 -0.192248 -1.020445 -0.812392   -0.351854   four -4.0 -5
# ...              ...       ...       ...         ...    ...  ... ..
# 2062-08-31 -0.922229 -2.214785 -1.755481   -1.343570    one -6.0 -5
# 2062-09-30 -0.353849 -0.170232 -0.114496   -0.495401    two -6.0 -5
# 2062-10-31 -2.533816 -0.057073 -0.021984   -0.759623  three -6.0 -5
# 2062-11-30 -2.399247 -0.729486 -0.135819   -1.375543   four -6.0 -5
# 2062-12-31 -0.635386 -0.249315 -0.981285   -1.633425  three -6.0 -5
#
# [600 rows x 7 columns]

# %% [markdown]
# ## Описательная статистика

# %% [markdown]
# Метод [`describe()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html#pandas.DataFrame.describe) показывает краткую статистическую сводку для данных:

# %%
df.describe()
# Out:
#                 A           B           C           D         F      G
# count  600.000000  600.000000  600.000000  600.000000  6.000000  600.0
# mean    -0.851589   -0.756812   -0.788894   -1.006383 -3.500000   -5.0
# std      0.625234    0.567575    0.584924    4.542093  1.870829    0.0
# min     -3.184246   -2.845246   -3.461886 -111.000000 -6.000000   -5.0
# 25%     -1.184371   -1.089441   -1.139980   -1.219287 -4.750000   -5.0
# 50%     -0.722379   -0.648769   -0.696077   -0.688548 -3.500000   -5.0
# 75%     -0.355033   -0.325918   -0.319679   -0.316519 -2.250000   -5.0
# max     -0.019063    0.000000   -0.000546   -0.000179 -1.000000   -5.0

# %% [markdown]
# Вычисление квантилей (для числовых признаков):

# %%
df_numeric.quantile(.1)
# Out:
# A   -1.778458
# B   -1.523740
# C   -1.598365
# D   -1.702961
# F   -5.500000
# G   -5.000000
# Name: 0.1, dtype: float64

# %% [markdown]
# Вычисление медианы (для числовых признаков):

# %%
df_numeric.median()
# Out:
# A   -0.722379
# B   -0.648769
# C   -0.696077
# D   -0.688548
# F   -3.500000
# G   -5.000000
# dtype: float64

# %% [markdown]
# Та же операция на другой оси (т.е. по строкам):

# %%
df_numeric.median(axis=1)
# Out:
# 2013-01-31   -2.065810
# 2013-02-28   -0.674144
# 2013-03-31   -1.596285
# 2013-04-30   -0.553194
# 2013-05-31   -0.916419
#                 ...
# 2062-08-31   -1.755481
# 2062-09-30   -0.353849
# 2062-10-31   -0.759623
# 2062-11-30   -1.375543
# 2062-12-31   -0.981285
# Freq: M, Length: 600, dtype: float64

# %% [markdown]
# Вычисление моды (для категориальных признаков):

# %%
numerical_columns = df_numeric.columns
all_columns = df.columns
cat_columns = list(set(all_columns) - set(numerical_columns))
df[cat_columns].mode()
# Out:
#        E
# 0    one
# 1  three

# %% [markdown]
# ## Объединение таблиц

# %% [markdown]
# ### Concat

# %% [markdown]
# Соединение таблиц вдоль выбранной оси
#
# `pd.concat(objs, axis=0, join='outer', ignore_index=False, copy=True, ...)`
#
# * `objs` &mdash; объединяемые таблицы;
# * `axis` : {`0` или `'index'`, `1` или `'columns'`} &mdash; ось индексов или ось колонок, иными словами соединение по вертикали или по горизонтали;
# * `join` : {`'inner'`, `'outer'`} &mdash; тип объединения &mdash; пересечение или объединение индексов/колонок;
# * `ignore_index` &mdash; сохранить индексы или определить и как $0, ..., n-1$;
# * `copy` &mdash; копировать данные или нет.

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])
print('df1:\n', df1)
df2 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']],
                   columns=['letter', 'number', 'animal'])
print('df2:\n', df2)
pd.concat([df1, df2])
# pd.concat([df1, df2], ignore_index=True)
# Out:
# df1:
#    letter  number
# 0      a       1
# 1      b       2
# df2:
#    letter  number animal
# 0      c       3    cat
# 1      d       4    dog
#   letter  number animal
# 0      a       1    NaN
# 1      b       2    NaN
# 0      c       3    cat
# 1      d       4    dog

# %% [markdown]
# ### Merge
#
# Слияние таблиц по вертикали путем выполнения операций слияния баз данных в стиле SQL.
#
# `pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, suffixes=('_x', '_y'), ...)`

# %%
# В обеих таблицах ключи повторяются

left = pd.DataFrame({'key': ['A', 'A'],
                     'lval': [1, 2]})
right = pd.DataFrame({'key': ['A', 'A'],
                      'rval': [4, 5]})

# %%
left
# Out:
#   key  lval
# 0   A     1
# 1   A     2

# %%
right
# Out:
#   key  rval
# 0   A     4
# 1   A     5

# %%
pd.merge(left, right, on='key')
# Out:
#   key  lval  rval
# 0   A     1     4
# 1   A     1     5
# 2   A     2     4
# 3   A     2     5

# %% [markdown]
# В результате объединения получаем 4 строки &mdash; для каждой строки из левой таблице есть две строки из правой таблицы с таким же ключом.

# %%
# В таблицах ключи не повторяются
left = pd.DataFrame({'key': ['A', 'B'],
                     'lval': [1, 2]})
right = pd.DataFrame({'key': ['A', 'B'],
                      'rval': [4, 5]})

# %%
left
# Out:
#   key  lval
# 0   A     1
# 1   B     2

# %%
right
# Out:
#   key  rval
# 0   A     4
# 1   B     5

# %%
pd.merge(left, right, on='key')
# Out:
#   key  lval  rval
# 0   A     1     4
# 1   B     2     5

# %% [markdown]
# В результате объединения получаем 2 строки &mdash; для каждой строки из левой таблице есть только одна строка из правой таблицы с таким же ключом.

# %% [markdown]
# Рассмотрим различные типы объединения. Сооздадим и напечатаем две таблицы.

# %%
left = pd.DataFrame({'lkey': ['A', 'B', 'C', 'A'],
                     'value': range(4)})
right = pd.DataFrame({'rkey': ['A', 'B', 'D', 'B'],
                      'value': range(4, 8)})

# %%
left
# Out:
#   lkey  value
# 0    A      0
# 1    B      1
# 2    C      2
# 3    A      3

# %%
right
# Out:
#   rkey  value
# 0    A      4
# 1    B      5
# 2    D      6
# 3    B      7

# %% [markdown]
# **Внешнее слияние** &mdash; используются ключи из объединения списков ключей. Иначе говоря, используются ключи, которые есть хотя бы в одной из таблиц. Если в другой таблице таких ключей нет, то ставятся пропуски.

# %%
pd.merge(left, right,
         left_on='lkey', right_on='rkey', how='outer')
# Out:
#   lkey  value_x rkey  value_y
# 0    A      0.0    A      4.0
# 1    A      3.0    A      4.0
# 2    B      1.0    B      5.0
# 3    B      1.0    B      7.0
# 4    C      2.0  NaN      NaN
# 5  NaN      NaN    D      6.0

# %% [markdown]
# **Внутреннее слияние** &mdash; используются ключи из пересечения списков ключей. Иначе говоря, используются ключи, которые присутствуют в обеих таблицах.

# %%
pd.merge(left, right,
         left_on='lkey', right_on='rkey', how='inner')
# Out:
#   lkey  value_x rkey  value_y
# 0    A        0    A        4
# 1    B        1    B        5
# 2    B        1    B        7
# 3    A        3    A        4

# %% [markdown]
# **Объединение по ключам левой таблицы.** Не используются ключи, которые есть в правой таблицы, но которых нет в левой. Если в правой таблице каких-то ключей нет, то ставятся пропуски.

# %%
pd.merge(left, right,
         left_on='lkey', right_on='rkey', how='left')
# Out:
#   lkey  value_x rkey  value_y
# 0    A        0    A      4.0
# 1    B        1    B      5.0
# 2    B        1    B      7.0
# 3    C        2  NaN      NaN
# 4    A        3    A      4.0

# %% [markdown]
# **Объединение по ключам правой таблицы.** Не используются ключи, которые есть в левой таблицы, но которых нет в правой. Если в левой таблице каких-то ключей нет, то ставятся пропуски.

# %%
pd.merge(left, right,
         left_on='lkey', right_on='rkey', how='right')
# Out:
#   lkey  value_x rkey  value_y
# 0    A      0.0    A        4
# 1    A      3.0    A        4
# 2    B      1.0    B        5
# 3  NaN      NaN    D        6
# 4    B      1.0    B        7

# %% [markdown]
# Выполним внутреннее объединение и установим ключ качестве индекса

# %%
pd.merge(left, right,
         left_on='lkey', right_on='rkey', how='inner') \
        .set_index('lkey')[['value_x', 'value_y']]
# Out:
#       value_x  value_y
# lkey
# A           0        4
# B           1        5
# B           1        7
# A           3        4

# %% [markdown]
# ## Группировка и сводные таблицы

# %% [markdown]
# Под группировкой (`"group by"`) понимаем процесс, включающий один или несколько следующих шагов:
#
# - Разделение (`Splitting`) данных на группы по некоторым критериям.
# - Независимое применение (`Applying`) функции к каждой группе.
# - Объединение (`Combining`) результатов в структуру данных.
#
# Подробнее см. в [Документации](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html#groupby)

# %% [markdown]
# Группировка выполняется функцией
#
# `df.groupby(by=None, axis=0, level=None, sort=True, ...)`
#
# Результатом группировки является объект, состоящий из пар (имя группы, подтаблица). Имя группы соответствует значению, по которому произведена группировка. К объекту-результату группировки применимы, например, следующие операции:
#
# * `for name, group in groupped: ... ` &mdash; цикл по группам;
# * `get_group(name)` &mdash; получить таблицу, соответствующую группе с именем `name`;
# * `groups` &mdash; получить все группы в виде словаря имя-подтаблица;
# * `count()` &mdash; количество значений в группах, исключая пропуски;
# * `size()` &mdash; размер групп;
# * `sum()`, `max()`, `min()`;
# * `mean()`, `median()`, `var()`, `std()`, `corr()`, `quantile(q)`;
# * `describe()` &mdash; вывод описательных статистик;
# * `aggregate(func)` &mdash; применение функции (или списка функций) `func` к группам.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'Животное' : ['Котик', 'Песик', 'Котик', 'Песик',
                  'Котик', 'Песик', 'Котик', 'Песик'],
    'Цвет шерсти' : ['белый', 'белый', 'коричневый', 'черный',
                     'коричневый', 'коричневый', 'белый', 'черный'],
    'Рост' : np.random.normal(5, 3, size=8),
    'Длина хвостика' : np.random.normal(10, 5, size=8)
})

df
# Out:
#   Животное Цвет шерсти      Рост  Длина хвостика
# 0    Котик       белый -2.261253       10.574709
# 1    Песик       белый  2.779390        5.510461
# 2    Котик  коричневый  5.289759        7.579589
# 3    Песик      черный  3.287708        4.064139
# 4    Котик  коричневый -3.882770       17.313697
# 5    Песик  коричневый  7.308826        8.365174
# 6    Котик       белый  7.317764        7.864653
# 7    Песик      черный  6.150507       11.266543

# %%
# Группировка, а затем применение функции mean() к полученным группам
df.groupby('Животное').mean() # не работает с группировками
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'белыйкоричневыйкоричневыйбелый' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Группировка, а затем применение функции mean() к полученным группам
# ----> 2 df.groupby('Животное').mean() # не работает с группировками
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
# df.groupby('Животное').agg('mean')

# %%
df.groupby('Животное').describe() # все основные параметры
# Out:
#           Рост                                                             \
#          count      mean       std      min       25%       50%       75%
# Животное
# Котик      4.0  1.615875  5.515922 -3.88277 -2.666633  1.514253  5.796760
# Песик      4.0  4.881608  2.195551  2.77939  3.160629  4.719108  6.440087
#
#                    Длина хвостика                                           \
#                max          count       mean       std       min       25%
# Животное
# Котик     7.317764            4.0  10.833162  4.526291  7.579589  7.793387
# Песик     7.308826            4.0   7.301579  3.190679  4.064139  5.148880
#
#
#                50%        75%        max
# Животное
# Котик     9.219681  12.259456  17.313697
# Песик     6.937818   9.090517  11.266543

# %%
# Группировка по двум колонкам и последующее применение операции суммирования
df.groupby(['Животное', 'Цвет шерсти']).sum()
# Out:
#                           Рост  Длина хвостика
# Животное Цвет шерсти
# Котик    белый        5.056511       18.439362
#          коричневый   1.406989       24.893286
# Песик    белый        2.779390        5.510461
#          коричневый   7.308826        8.365174
#          черный       9.438215       15.330682

# %%
# Группировка по двум колонкам и последующее применение операции суммирования
df.groupby(['Животное', 'Цвет шерсти']).mean()
# Out:
#                           Рост  Длина хвостика
# Животное Цвет шерсти
# Котик    белый        2.528255        9.219681
#          коричневый   0.703494       12.446643
# Песик    белый        2.779390        5.510461
#          коричневый   7.308826        8.365174
#          черный       4.719108        7.665341

# %% [markdown]
# Полученная таблица имеет мультииндекс

# %%
df.groupby(['Животное', 'Цвет шерсти']).sum().index
# Out:
# MultiIndex([('Котик',      'белый'),
#             ('Котик', 'коричневый'),
#             ('Песик',      'белый'),
#             ('Песик', 'коричневый'),
#             ('Песик',     'черный')],
#            names=['Животное', 'Цвет шерсти'])

# %% [markdown]
# Метод [`stack()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html#pandas.DataFrame.stack) "сжимает" уровень в столбцах DataFrame.

# %%
stacked = df.stack()
stacked
# Out:
# 0  Животное               Котик
#    Цвет шерсти            белый
#    Рост               -2.261253
#    Длина хвостика     10.574709
# 1  Животное               Песик
#    Цвет шерсти            белый
#    Рост                 2.77939
#    Длина хвостика      5.510461
# 2  Животное               Котик
#    Цвет шерсти       коричневый
#    Рост                5.289759
#    Длина хвостика      7.579589
# 3  Животное               Песик
#    Цвет шерсти           черный
#    Рост                3.287708
#    Длина хвостика      4.064139
# 4  Животное               Котик
#    Цвет шерсти       коричневый
#    Рост                -3.88277
#    Длина хвостика     17.313697
# 5  Животное               Песик
#    Цвет шерсти       коричневый
#    Рост                7.308826
#    Длина хвостика      8.365174
# 6  Животное               Котик
#    Цвет шерсти            белый
#    Рост                7.317764
#    Длина хвостика      7.864653
# 7  Животное               Песик
#    Цвет шерсти           черный
#    Рост                6.150507
#    Длина хвостика     11.266543
# dtype: object

# %% [markdown]
# С "уложенными" (`"stacked"`) DataFrame или Series (имеющими MultiIndex в качестве индекса) обратная операция - [`unstack()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.unstack.html#pandas.DataFrame.unstack), которая по умолчанию распаковывает последний уровень:

# %%
stacked.unstack()
# Out:
#   Животное Цвет шерсти       Рост Длина хвостика
# 0    Котик       белый   4.964573       9.798898
# 1    Песик       белый   5.755154      20.015283
# 2    Котик  коричневый  -0.399278       8.070953
# 3    Песик      черный   8.007278      10.494533
# 4    Котик  коричневый   1.823567       3.331647
# 5    Песик  коричневый   0.152815       7.909495
# 6    Котик       белый   1.155659       10.52267
# 7    Песик      черный  10.696467      14.815434

# %% [markdown]
# ### Сводные таблицы (Pivot tables)

# %% [markdown]
# См. секцию [Документации](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html#reshaping-pivot)

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                   'B': ['A', 'B', 'C'] * 4,
                   'C': ['red', 'red', 'red', 'blue', 'blue', 'blue'] * 2,
                   'D': np.random.randn(12),
                   'E': np.random.randn(12)})
df
# Out:
#         A  B     C         D         E
# 0     one  A   red  1.195107  1.116852
# 1     one  B   red  0.517803 -0.144250
# 2     two  C   red -2.203994 -1.159668
# 3   three  A  blue -1.475034 -2.077227
# 4     one  B  blue -0.234323 -2.158244
# 5     one  C  blue  1.241851  1.085581
# 6     two  A   red -0.808200  0.285629
# 7   three  B   red -0.817351  1.286630
# 8     one  C   red -0.341536 -2.193996
# 9     one  A  blue  1.776653 -0.686398
# 10    two  B  blue  0.122834 -1.633954
# 11  three  C  blue -0.081016  0.371996

# %%
import matplotlib # стандартный модуль по графикам, основа tkinter
import matplotlib.pyplot as plt

# %%
df[['D', 'E']].boxplot()
# Out:
# <Axes: >

# %%
df[['D', 'E']].hist()
plt.show()

# %%
df[['E']].hist()
plt.show()

# %% [markdown]
# Мы можем очень легко создать сводные таблицы из этих данных:

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C            blue       red
# A     B
# one   A  1.776653  1.195107
#       B -0.234323  0.517803
#       C  1.241851 -0.341536
# three A -1.475034       NaN
#       B       NaN -0.817351
#       C -0.081016       NaN
# two   A       NaN -0.808200
#       B  0.122834       NaN
#       C       NaN -2.203994

# %% [markdown]
# ## Временные ряды

# %% [markdown]
# pandas имеет простые, мощные и эффективные функции для выполнения операций передискретизации во время преобразования частоты (например, преобразование секундных данных в 5-минутные данные). См. [документацию по временным рядам](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries).

# %%
rng = pd.date_range('11/12/2024', periods=100, freq='s') #распредление по секундам по дню
rng[:10]
# Out:
# DatetimeIndex(['2024-11-12 00:00:00', '2024-11-12 00:00:01',
#                '2024-11-12 00:00:02', '2024-11-12 00:00:03',
#                '2024-11-12 00:00:04', '2024-11-12 00:00:05',
#                '2024-11-12 00:00:06', '2024-11-12 00:00:07',
#                '2024-11-12 00:00:08', '2024-11-12 00:00:09'],
#               dtype='datetime64[ns]', freq='s')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts[:10]
# Out:
# 2024-11-12 00:00:00    133
# 2024-11-12 00:00:01    227
# 2024-11-12 00:00:02    310
# 2024-11-12 00:00:03    488
# 2024-11-12 00:00:04     51
# 2024-11-12 00:00:05    351
# 2024-11-12 00:00:06     57
# 2024-11-12 00:00:07    109
# 2024-11-12 00:00:08      8
# 2024-11-12 00:00:09    230
# Freq: s, dtype: int32

# %%
ts.resample('5Min').sum() # агрегация
# Out:
# 2024-11-12    26642
# Freq: 5min, dtype: int32

# %% [markdown]
# Представление часового пояса:

# %%
rng = pd.date_range('3/6/2024 00:00', periods=5, freq='D')
rng
# Out:
# DatetimeIndex(['2024-03-06', '2024-03-07', '2024-03-08', '2024-03-09',
#                '2024-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2024-03-06    0.942430
# 2024-03-07    1.100857
# 2024-03-08    0.639684
# 2024-03-09   -0.120510
# 2024-03-10    0.390963
# Freq: D, dtype: float64

# %%
ts
# Out:
# 2024-03-06    0.942430
# 2024-03-07    1.100857
# 2024-03-08    0.639684
# 2024-03-09   -0.120510
# 2024-03-10    0.390963
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2024-03-06 00:00:00+00:00    0.942430
# 2024-03-07 00:00:00+00:00    1.100857
# 2024-03-08 00:00:00+00:00    0.639684
# 2024-03-09 00:00:00+00:00   -0.120510
# 2024-03-10 00:00:00+00:00    0.390963
# Freq: D, dtype: float64

# %% [markdown]
# Преобразование в другой часовой пояс:

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2024-03-05 19:00:00-05:00    0.942430
# 2024-03-06 19:00:00-05:00    1.100857
# 2024-03-07 19:00:00-05:00    0.639684
# 2024-03-08 19:00:00-05:00   -0.120510
# 2024-03-09 19:00:00-05:00    0.390963
# Freq: D, dtype: float64

# %% [markdown]
# Преобразование между представлениями промежутка времени:

# %%
rng = pd.date_range('1/1/2024', periods=5, freq='ME') # ME - конец месяца
rng
# Out:
# DatetimeIndex(['2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
rng = pd.date_range('2024/12/30', periods=5, freq='ME') # ME - конец месяца, парсер дат - format="%Y-%d-%m"
rng
# Out:
# DatetimeIndex(['2024-12-31', '2025-01-31', '2025-02-28', '2025-03-31',
#                '2025-04-30'],
#               dtype='datetime64[ns]', freq='ME')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2024-12-31   -0.884407
# 2025-01-31   -0.957348
# 2025-02-28    0.914152
# 2025-03-31   -0.422694
# 2025-04-30    0.144604
# Freq: ME, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2024-12   -0.884407
# 2025-01   -0.957348
# 2025-02    0.914152
# 2025-03   -0.422694
# 2025-04    0.144604
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2024-12-01   -0.884407
# 2025-01-01   -0.957348
# 2025-02-01    0.914152
# 2025-03-01   -0.422694
# 2025-04-01    0.144604
# Freq: MS, dtype: float64

# %% [markdown]
# Преобразование между периодом и меткой времени позволяет использовать некоторые удобные арифметические функции. В следующем примере мы преобразуем ежеквартальную частоту с годом, заканчивающимся в ноябре, в 9 утра конца месяца, следующего за концом квартала:

# %%
prng = pd.period_range('2022Q1', '2023Q4', freq='Q-NOV')
prng
# Out:
# PeriodIndex(['2022Q1', '2022Q2', '2022Q3', '2022Q4', '2023Q1', '2023Q2',
#              '2023Q3', '2023Q4'],
#             dtype='period[Q-NOV]')

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)
ts[:10]
# Out:
# 2022Q1    0.839756
# 2022Q2    0.430286
# 2022Q3   -1.100547
# 2022Q4   -1.312115
# 2023Q1    1.194278
# 2023Q2   -1.640146
# 2023Q3    1.537327
# 2023Q4    0.389223
# Freq: Q-NOV, dtype: float64

# %%
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('h', 's') + 9
ts[:10]
# Out:
# 2022-03-01 09:00    0.839756
# 2022-06-01 09:00    0.430286
# 2022-09-01 09:00   -1.100547
# 2022-12-01 09:00   -1.312115
# 2023-03-01 09:00    1.194278
# 2023-06-01 09:00   -1.640146
# 2023-09-01 09:00    1.537327
# 2023-12-01 09:00    0.389223
# Freq: h, dtype: float64

# %%
ts.head()
# Out:
# 2022-03-01 09:00    0.839756
# 2022-06-01 09:00    0.430286
# 2022-09-01 09:00   -1.100547
# 2022-12-01 09:00   -1.312115
# 2023-03-01 09:00    1.194278
# Freq: h, dtype: float64

# %% [markdown]
# ## Новая и улучшенная агрегатная функция

# %% [markdown]
# ## Новая и улучшенная агрегатная функция
#
# В pandas 0.20.0 была добавлена функция [`agg`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.agg.html), которая значительно упрощает суммирование данных аналогично groupby.
#
# Чтобы проиллюстрировать ее функциональность, предположим, что нам нужно получить сумму в столбцах `D` и `E`, а также среднее значение столбца `E`.
#
# Процесс не очень удобный:

# %%
ts.values
# Out:
# array([ 0.8397561 ,  0.43028606, -1.10054692, -1.3121153 ,  1.19427848,
#        -1.64014647,  1.5373269 ,  0.38922324])

# %%
time_df = pd.DataFrame(columns=['time', 'values'])

# %%
time_df
# Out:
#         time    values
# 0 2024-12-31  0.839756
# 1 2025-01-31  0.839756
# 2 2025-02-28  0.839756
# 3 2025-03-31  0.839756
# 4 2025-04-30  0.839756

# %%
time_df['time'] = rng.to_numpy()

# %%
time_df['values'] = ts.values[0]

# %%
time_df.agg(['sum', 'mean', 'count', 'min', 'max'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 time_df.agg(['sum', 'mean', 'count', 'min', 'max'])
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\frame.py:10149, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#   10146 axis = self._get_axis_number(axis)
#   10148 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# > 10149 result = op.agg()
#   10150 result = reconstruct_and_relabel_result(result, func, **kwargs)
#   10151 return result
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:928, in FrameApply.agg(self)
#     926 result = None
#     927 try:
# --> 928     result = super().agg()
#     929 finally:
#     930     self.obj = obj
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
#     195 if callable(func):
#     196     f = com.get_cython_func(func)
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:326, in Apply.agg_list_like(self)
#     318 def agg_list_like(self) -> DataFrame | Series:
#     319     """
#     320     Compute aggregation in the case of a list-like argument.
#     321
#    (...)
#     324     Result of aggregation.
#     325     """
# --> 326     return self.agg_or_apply_list_like(op_name="agg")
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:744, in NDFrameApply.agg_or_apply_list_like(self, op_name)
#     741 if getattr(obj, "axis", 0) == 1:
#     742     raise NotImplementedError("axis other than 0 is not supported")
# --> 744 keys, results = self.compute_list_like(op_name, obj, kwargs)
#     745 result = self.wrap_results_list_like(keys, results)
#     746 return result
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:385, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     379 colg = obj._gotitem(col, ndim=1, subset=selected_obj.iloc[:, index])
#     380 args = (
#     381     [self.axis, *self.args]
#     382     if include_axis(op_name, colg)
#     383     else self.args
#     384 )
# --> 385 new_res = getattr(colg, op_name)(func, *args, **kwargs)
#     386 results.append(new_res)
#     387 indices.append(index)
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\series.py:4766, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4763     func = dict(kwargs.items())
#    4765 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4766 result = op.agg()
#    4767 return result
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:1430, in SeriesApply.agg(self)
#    1429 def agg(self):
# -> 1430     result = super().agg()
#    1431     if result is None:
#    1432         obj = self.obj
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
#     195 if callable(func):
#     196     f = com.get_cython_func(func)
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:326, in Apply.agg_list_like(self)
#     318 def agg_list_like(self) -> DataFrame | Series:
#     319     """
#     320     Compute aggregation in the case of a list-like argument.
#     321
#    (...)
#     324     Result of aggregation.
#     325     """
# --> 326     return self.agg_or_apply_list_like(op_name="agg")
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:744, in NDFrameApply.agg_or_apply_list_like(self, op_name)
#     741 if getattr(obj, "axis", 0) == 1:
#     742     raise NotImplementedError("axis other than 0 is not supported")
# --> 744 keys, results = self.compute_list_like(op_name, obj, kwargs)
#     745 result = self.wrap_results_list_like(keys, results)
#     746 return result
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:369, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     363 colg = obj._gotitem(selected_obj.name, ndim=1, subset=selected_obj)
#     364 args = (
#     365     [self.axis, *self.args]
#     366     if include_axis(op_name, colg)
#     367     else self.args
#     368 )
# --> 369 new_res = getattr(colg, op_name)(a, *args, **kwargs)
#     370 results.append(new_res)
#     372 # make sure we find a good name
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\series.py:4766, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4763     func = dict(kwargs.items())
#    4765 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4766 result = op.agg()
#    4767 return result
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:1430, in SeriesApply.agg(self)
#    1429 def agg(self):
# -> 1430     result = super().agg()
#    1431     if result is None:
#    1432         obj = self.obj
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:187, in Apply.agg(self)
#     184 kwargs = self.kwargs
#     186 if isinstance(func, str):
# --> 187     return self.apply_str()
#     189 if is_dict_like(func):
#     190     return self.agg_dict_like()
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:603, in Apply.apply_str(self)
#     601         else:
#     602             self.kwargs["axis"] = self.axis
# --> 603 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\apply.py:693, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     691 f = getattr(obj, func)
#     692 if callable(f):
# --> 693     return f(*args, **kwargs)
#     695 # people may aggregate on a non-callable attribute
#     696 # but don't let them think they can pass args to it
#     697 assert len(args) == 0
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\series.py:6528, in Series.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#    6519 @doc(make_doc("sum", ndim=1))
#    6520 def sum(
#    6521     self,
#    (...)
#    6526     **kwargs,
#    6527 ):
# -> 6528     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\generic.py:12506, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12498 def sum(
#   12499     self,
#   12500     axis: Axis | None = 0,
#    (...)
#   12504     **kwargs,
#   12505 ):
# > 12506     return self._min_count_stat_function(
#   12507         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12508     )
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\generic.py:12489, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12486 elif axis is lib.no_default:
#   12487     axis = 0
# > 12489 return self._reduce(
#   12490     func,
#   12491     name=name,
#   12492     axis=axis,
#   12493     skipna=skipna,
#   12494     numeric_only=numeric_only,
#   12495     min_count=min_count,
#   12496 )
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\series.py:6443, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6439     self._get_axis_number(axis)
#    6441 if isinstance(delegate, ExtensionArray):
#    6442     # dispatch to ExtensionArray interface
# -> 6443     return delegate._reduce(name, skipna=skipna, **kwds)
#    6445 else:
#    6446     # dispatch to numpy arrays
#    6447     if numeric_only and self.dtype.kind not in "iufcb":
#    6448         # i.e. not is_numeric_dtype(self.dtype)
#
# File c:\Users\user\Documents\new-python-repo\.folder\Lib\site-packages\pandas\core\arrays\base.py:1954, in ExtensionArray._reduce(self, name, skipna, keepdims, **kwargs)
#    1952 meth = getattr(self, name, None)
#    1953 if meth is None:
# -> 1954     raise TypeError(
#    1955         f"'{type(self).__name__}' with dtype {self.dtype} "
#    1956         f"does not support reduction '{name}'"
#    1957     )
#    1958 result = meth(skipna=skipna, **kwargs)
#    1959 if keepdims:
#
# TypeError: 'DatetimeArray' with dtype datetime64[ns] does not support reduction 'sum'

# %%
time_df.agg(['sum', 'mean', 'count', 'min', 'max'])

# %%
get_year = lambda x: x.year

# %%
time_df['time'][0].year
# Out:
# 2024

# %%
time_df.agg({'values': ['sum', 'mean', 'count', 'min', 'max'], 'time': [get_year]})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19288\546378006.py:1: FutureWarning: using <function <lambda> at 0x00000142109454E0> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   time_df.agg({'values': ['sum', 'mean', 'count', 'min', 'max'], 'time': [get_year]})
#          values     time
#          values <lambda>
# sum    4.198780      NaN
# mean   0.839756      NaN
# count  5.000000      NaN
# min    0.839756      NaN
# max    0.839756      NaN
# 0           NaN   2024.0
# 1           NaN   2025.0
# 2           NaN   2025.0
# 3           NaN   2025.0
# 4           NaN   2025.0

# %%
df
# Out:
#         A  B     C         D         E
# 0     one  A   red  1.195107  1.116852
# 1     one  B   red  0.517803 -0.144250
# 2     two  C   red -2.203994 -1.159668
# 3   three  A  blue -1.475034 -2.077227
# 4     one  B  blue -0.234323 -2.158244
# 5     one  C  blue  1.241851  1.085581
# 6     two  A   red -0.808200  0.285629
# 7   three  B   red -0.817351  1.286630
# 8     one  C   red -0.341536 -2.193996
# 9     one  A  blue  1.776653 -0.686398
# 10    two  B  blue  0.122834 -1.633954
# 11  three  C  blue -0.081016  0.371996

# %%
df[["D", "E"]].sum()
# Out:
# D   -1.107205
# E   -5.907051
# dtype: float64

# %%
df["E"].mean()
# Out:
# np.float64(-0.4922542719722603)

# %% [markdown]
# Это работает, но нужно дополнительно пояснять что было сделано.
#
# Новый `agg` упрощает процесс и на выходе таблица со значениями.

# %%
df[["D", "E"]].agg(['sum', 'mean', 'count', 'min', 'max'])
# Out:
#                D          E
# sum    -1.107205  -5.907051
# mean   -0.092267  -0.492254
# count  12.000000  12.000000
# min    -2.203994  -2.193996
# max     1.776653   1.286630

# %% [markdown]
# Другая запись будет выглядеть следующим образом. Укажем для столбцов явно какие столбцы в `agg` и укажем, какие операции применять к каждому столбцу.

# %%
df.agg({'E': ['sum', 'mean'], 'D': ['sum']})
# Out:
#              E         D
# sum  -3.245641 -7.223554
# mean -0.270470       NaN

# %% [markdown]
# Чтобы агрегировать данные и использовать функцию `mode` по работе с текстом, применим лямбда-функцию, которая использует `value_counts`:

# %%
get_max = lambda x: x.value_counts(dropna=False)

# %% [markdown]
# Затем, включить наиболее часто используемые  значения в сводную таблицу:

# %%
df
# Out:
#         A  B     C         D         E
# 0     one  A   red  1.195107  1.116852
# 1     one  B   red  0.517803 -0.144250
# 2     two  C   red -2.203994 -1.159668
# 3   three  A  blue -1.475034 -2.077227
# 4     one  B  blue -0.234323 -2.158244
# 5     one  C  blue  1.241851  1.085581
# 6     two  A   red -0.808200  0.285629
# 7   three  B   red -0.817351  1.286630
# 8     one  C   red -0.341536 -2.193996
# 9     one  A  blue  1.776653 -0.686398
# 10    two  B  blue  0.122834 -1.633954
# 11  three  C  blue -0.081016  0.371996

# %%
df.agg({'D': ['sum', 'mean'], 'E': ['sum', 'mean'], 'A': [get_max]})
# Out:
#               D         E        A
#               D         E <lambda>
# sum   -1.107205 -5.907051      NaN
# mean  -0.092267 -0.492254      NaN
# one         NaN       NaN      6.0
# two         NaN       NaN      3.0
# three       NaN       NaN      3.0

# %%
get_max.__name__ = "most frequent"

# %% [markdown]
# Но в этом подходе: в столбце написано `<lambda>`.
#
# В идеале указать `most frequent` (*наиболее часто*). Можно явно поменять название функции:

# %%
get_max.__name__ = "most frequent"

# %% [markdown]
# Теперь, агрегирование:

# %%
df.agg({'D': ['sum', 'mean'], 'E': ['sum', 'mean'], 'A': [get_max]})
# Out:
#               D         E             A
#               D         E most frequent
# sum   -7.223554 -3.245641           NaN
# mean  -0.601963 -0.270470           NaN
# one         NaN       NaN           6.0
# two         NaN       NaN           3.0
# three       NaN       NaN           3.0

# %% [markdown]
# В качестве завершения финальный бонус.
#
# Агрегатная (aggregate) функция, использующая словарь, полезна, но проблема заключается в том, что она не сохраняет порядок.
#
# Если необходимо убедиться, что столбцы расположены в определенном порядке, можно использовать [`OrderedDict`](https://docs.python.org/3/library/collections.html#collections.OrderedDict):

# %%
import collections
f = collections.OrderedDict([('A', [get_max]), ('D', ['sum', 'mean']), ('E', ['sum', 'mean'])])
df.agg(f)
# Out:
#                   A         D         E
#       most frequent         D         E
# one             6.0       NaN       NaN
# two             3.0       NaN       NaN
# three           3.0       NaN       NaN
# sum             NaN -7.223554 -3.245641
# mean            NaN -0.601963 -0.270470

# %% [markdown]
# ## Получение и запись данных

# %% [markdown]
# ### CSV

# %% [markdown]
# см. [про запись в csv файлы](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#io-store-in-csv)

# %%
df.to_csv('foo.csv')

# %% [markdown]
# см. [про чтенеи csv файлов](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#io-read-csv-table)

# %%
pd.read_csv('foo.csv')
# Out:
#     Unnamed: 0      A  B     C         D         E
# 0            0    one  A   red -1.858931 -0.573762
# 1            1    one  B   red -2.479307  1.908843
# 2            2    two  C   red -0.337012 -0.075287
# 3            3  three  A  blue  1.969856 -0.597402
# 4            4    one  B  blue  0.245826 -0.264284
# 5            5    one  C  blue  0.725448  0.417956
# 6            6    two  A   red -0.265341 -1.036288
# 7            7  three  B   red -0.441735 -1.119077
# 8            8    one  C   red -0.471247  0.846928
# 9            9    one  A  blue  0.384062  0.242129
# 10          10    two  B  blue  1.303241 -0.530112
# 11          11  three  C  blue -0.085511  0.087011

# %% [markdown]
# ### HDF5

# %% [markdown]
# см. про чтение и запись в [`HDFStores`](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#io-hdf5)

# %% [markdown]
# Запись в `HDF5` хранилище:

# %%
df.to_hdf('foo.h5', 'df')

# %% [markdown]
# Чтение из `HDF5` хранилища:

# %%
pd.read_hdf('foo.h5', 'df')
# Out:
#         A  B     C         D         E
# 0     one  A   red -1.858931 -0.573762
# 1     one  B   red -2.479307  1.908843
# 2     two  C   red -0.337012 -0.075287
# 3   three  A  blue  1.969856 -0.597402
# 4     one  B  blue  0.245826 -0.264284
# 5     one  C  blue  0.725448  0.417956
# 6     two  A   red -0.265341 -1.036288
# 7   three  B   red -0.441735 -1.119077
# 8     one  C   red -0.471247  0.846928
# 9     one  A  blue  0.384062  0.242129
# 10    two  B  blue  1.303241 -0.530112
# 11  three  C  blue -0.085511  0.087011

# %% [markdown]
# ### Excel

# %% [markdown]
# см. [про чтение и запись в MS Excel](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#io-excel)

# %% [markdown]
# Запись в excel файл:

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %% [markdown]
# Чтение из excel файла:

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#     Unnamed: 0      A  B     C         D         E
# 0            0    one  A   red -1.858931 -0.573762
# 1            1    one  B   red -2.479307  1.908843
# 2            2    two  C   red -0.337012 -0.075287
# 3            3  three  A  blue  1.969856 -0.597402
# 4            4    one  B  blue  0.245826 -0.264284
# 5            5    one  C  blue  0.725448  0.417956
# 6            6    two  A   red -0.265341 -1.036288
# 7            7  three  B   red -0.441735 -1.119077
# 8            8    one  C   red -0.471247  0.846928
# 9            9    one  A  blue  0.384062  0.242129
# 10          10    two  B  blue  1.303241 -0.530112
# 11          11  three  C  blue -0.085511  0.087011
