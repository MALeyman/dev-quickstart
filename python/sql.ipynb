# %% [markdown]
# # postgresql
# -------------------
#
# ```bash
#
# sudo apt install postgresql  	    #  Установить SQL
# sudo service postgresql start       #  запуск сервера  PostgreSQL
# sudo service postgresql status      #  проверка запуска
# sudo -u postgres psql               # подключение к PostgreSQL
#
#
#
# ```

# %% [markdown]
# \q      -	выход    из SQL
# \l      -	 Список всех БД
# exit    -	 выход из prompt
#
# sudo -u postgres psql  - подключение к PostgreSQL
#
# ALTER ROLE postgres WITH SUPERUSER;
# ALTER USER postgres WITH PASSWORD 'postgres';
#
# create user postgres password 'postgres';   -  создание пользователя
# create database baseName2 owner postgres;   - создание базы
# ALTER USER postgres WITH PASSWORD 'postgres';  - изменить пароль пользователя  postgres
#
#
# Ctrl+D чтобы выйти.
#
# 1. В терминале выполним команды:
# sudo nano /etc/postgresql/17/main/postgresql.conf
# Нам нужно найти строчку, убрать решетку в начале:
# listen_addresses = ‘localhost’
# И заменить ее на:
# listen_addresses = ‘*’
# Дальше
# sudo nano /etc/postgresql/17/main/pg_hba.conf
# добавляем строку вместо maks  имя  пользователя
# host all all  all  md5
#
# sudo service postgresql restart   - перезапуск сервера
#
# Восстановление базы данных
# pg_restore -U postgres -d BikeStore -j 2 ~/Рабочий\ стол/sql/dump-BikeStore/
#
# Либо так
# cp /home/maksim/Downloads/bike_store.sql /tmp
# sudo -u postgres psql -d BikeStore -f /tmp/bike_store.sql
#
# Создание Дампа (Резервная копия)
# pg_dump -U postgres -d BikeStore -F p -f /~/Рабочий стол/sql/dump-BikeStore/
#
# pg_dump -U postgres -d BikeStore -F p -f ~/Desktop/bike_store.sql
